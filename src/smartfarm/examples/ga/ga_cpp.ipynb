# %%
# Import necessary modules
import numpy as np
import os
import pandas as pd
import pickle
import sys

here = os.path.dirname(os.path.abspath("__file__"))
project_root = os.path.abspath(os.path.join(here, '../../'))
sys.path.insert(0, project_root)

from core.ga.ga_bounds import DesignSpaceBounds
from core.ga.ga_params import GeneticAlgorithmParams
from core.ga.ga import GeneticAlgorithm

from core.model.model_carrying_capacities import ModelCarryingCapacities
from core.model.model_disturbances import ModelDisturbances
from core.model.model_growth_rates import ModelGrowthRates
from core.model.model_initial_conditions import ModelInitialConditions
from core.model.model_params import ModelParams
from core.model.model_typical_disturbances import ModelTypicalDisturbances
from core.model.model_sensitivities import ModelSensitivities

from ga_member_cpp import Evaluator

# %%
input_key = 10

# %% [markdown]
# ## Model Parameters

# %%
# Set ModelParams (time stepping)
model_params = ModelParams(
    dt               = 1.0,  # hours/step
    simulation_hours = 2900, # hours
    verbose          = True  # for the single simulation
)

# %%
# Set ModelCarryingCapacities
carrying_capacities = ModelCarryingCapacities(
    kh = 3.0,  # m
    kA = 0.65, # m2
    kN = 20,   # number of leaves
    kc = 1000, # number of spikelets
    kP = 0.25  # kg
)

# %%
# Set ModelGrowthRates
growth_rates = ModelGrowthRates(
    ah = 0.01,   # 1/hr
    aA = 0.0105, # 1/hr
    aN = 0.011,  # 1/hr
    ac = 0.01,   # 1/hr
    aP = 0.005   # 1/hr
)

# %%
# Set ModelSensitivities
sensitivities = ModelSensitivities(
    sigma_W = 30,  # hrs
    sigma_F = 300, # hrs
    sigma_T = 30,  # hrs
    sigma_R = 30   # hrs
)

# %%
# Set ModelInitialConditions
initial_conditions = ModelInitialConditions(
    h0=carrying_capacities.kh/model_params.simulation_hours, # m/hr
    A0=carrying_capacities.kA/model_params.simulation_hours, # m2/hr
    N0=carrying_capacities.kN/model_params.simulation_hours, # number/hr
    c0=carrying_capacities.kc/model_params.simulation_hours, # number/hr
    P0=carrying_capacities.kP/model_params.simulation_hours  # kg/hr
)

# %% [markdown]
# ## Design Space

# %%
lower_bounds_dict = {
    "irrigation_frequency":    12, # once every X hours
    "irrigation_amount":       0,  # inches per irrigation
    "fertilization_frequency": 24, # once every X hours (once a day)
    "fertilization_amount":    0   # pounds per fertilization
}
lower_bounds = np.array([value for key, value in lower_bounds_dict.items()])

# %%
upper_bounds_dict = {
    "irrigation_frequency":    2900,  # once a season
    "irrigation_amount":       10,    # inches per irrigation
    "fertilization_frequency": 2900,  # once a season
    "fertilization_amount":    700    # pounds per fertilization
}
upper_bounds = np.array([value for key, value in upper_bounds_dict.items()])

# %%
# Set DesignSpaceBounds
bounds = DesignSpaceBounds(
    lower_bounds=lower_bounds,
    upper_bounds=upper_bounds
)

# %% [markdown]
# ## Genetic Algorithm Parameters

# %%
# Genetic algorithm style inputs
ga_params = GeneticAlgorithmParams(
    num_parents     = 16,  # number of design strings to breed
    num_kids        = 16,  # number of offspring design strings
    num_generations = 100, # number of generations
    num_members     = 128, # number of simulations per generation
)

# %% [markdown]
# ## Input Disturbances

# %%
# Hourly precipitation, radiation, and temperature from CSV
hourly_input_disturbances = pd.read_csv(
    '../../io/inputs/hourly_prcp_rad_temp_iowa.csv'
)

# %%
# Set ModelDisturbances
input_disturbances = ModelDisturbances(
    precipitation = hourly_input_disturbances['Hourly Precipitation (in)'].to_numpy(), # drought year
    radiation     = hourly_input_disturbances['Hourly Radiation (W/m2)'].to_numpy(),
    temperature   = hourly_input_disturbances['Temperature (C)'].to_numpy()
)

# %% [markdown]
# ## Optimal/Typical Values

# %%
default_typical_disturbances = ModelTypicalDisturbances()

typical_disturbances = ModelTypicalDisturbances(
    typical_water       = default_typical_disturbances.typical_water       * model_params.dt,
    typical_fertilizer  = default_typical_disturbances.typical_fertilizer  * model_params.dt,
    typical_temperature = default_typical_disturbances.typical_temperature * model_params.dt,
    typical_radiation   = default_typical_disturbances.typical_radiation   * model_params.dt
)

# %% [markdown]
# ## Single simulation

# %%
# Carla test params
irrigation_frequency = 24 * 7 * 2  # Irrigate once every 336 hours
irrigation_amount    = 0.23        # with 0.23 inches per irrigation (goal is 28 in including precip)
fertilizer_frequency = 24 * 30 * 3 # Fertilize once every 2160 hours
fertilizer_amount    = 175         # with 175 lbs per fertilization (goal is 355 lbs over season)

'''
# Example bad params
irrigation_frequency = 1
irrigation_amount    = 0
fertilizer_frequency = 1
fertilizer_amount    = 0
'''
# Out:
# '\n# Example bad params\nirrigation_frequency = 1\nirrigation_amount    = 0\nfertilizer_frequency = 1\nfertilizer_amount    = 0\n'

# %%
# Construct a single-member population Evaluator
from core.ga.ga_population import Population
population = Population(
    bounds               = bounds,
    ga_params            = ga_params,
    carrying_capacities  = carrying_capacities,
    disturbances         = input_disturbances,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    model_params         = model_params,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities,
    values = np.array([[irrigation_frequency, irrigation_amount, fertilizer_frequency, fertilizer_amount]])
)

# %%
population.set_costs_with_cpp()
cost_cpp = population.costs[0]
print(f"Cost from C++ Evaluator: {cost_cpp}")
# Out:
# Time taken to evaluate population with C++ evaluator: 0.0031061172485351562 seconds
# Cost from C++ Evaluator: -603.6537164537001

# %%
population.set_costs()
cost_py = population.costs[0]
print(f"Cost from Python Evaluator: {cost_py}")
# Out:
# Cost from Python Evaluator: -607.4450492586295

# %%
import time, numpy as np

# 1) context build
t0 = time.perf_counter()
ctx = population._build_sim_context_dict_cpp()
t1 = time.perf_counter()

# 2) evaluator construction
from ga_member_cpp import Evaluator
ev = Evaluator(ctx)
t2 = time.perf_counter()

# 3) evaluation (all 128)
X = np.ascontiguousarray(population.values, dtype=np.float64)  # IMPORTANT
costs = ev.evaluate_population(X)
t3 = time.perf_counter()

print("build ctx:", t1-t0)
print("make eval:", t2-t1)
print("eval pop :", t3-t2)
# Out:
# build ctx: 0.0029269999358803034
# make eval: 0.0015197498723864555
# eval pop : 0.0032545002177357674

# %% [markdown]
# ## Genetic Algorithm

# %%
# Set verbose to False for GA runs
model_params.verbose = False

# Create GeneticAlgorithm object from all inputs
GeneticAlgorithm = GeneticAlgorithm(
    bounds               = bounds,
    ga_params            = ga_params,
    model_params         = model_params,
    carrying_capacities  = carrying_capacities,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    disturbances         = input_disturbances,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities
)

# %%
# Run the Genetic Algorithm and save the result

GeneticAlgorithmResult = GeneticAlgorithm.run_with_cpp()

with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "wb") as f:
    pickle.dump(GeneticAlgorithmResult, f)
# Out:
# Time taken to evaluate population with C++ evaluator: 0.39409685134887695 seconds
# Time taken to calculate costs for g=0: 0.3983452320098877 seconds
# Generation 2 of 100
# Time taken to breed kids for g=1: 0.0006549358367919922 seconds
# Time taken to fill random members for g=1: 0.0005743503570556641 seconds
# Time taken to evaluate population with C++ evaluator: 0.3962979316711426 seconds
# Time taken to calculate costs for g=1: 0.40018796920776367 seconds
# Lowest cost in generation 1: -982.99
# Time taken to sort population for g=1: 9.322166442871094e-05 seconds
# Generation 3 of 100
# Time taken to breed kids for g=2: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=2: 0.0007262229919433594 seconds
# Time taken to evaluate population with C++ evaluator: 0.3912837505340576 seconds
# Time taken to calculate costs for g=2: 0.3952770233154297 seconds
# Lowest cost in generation 2: -987.83
# Time taken to sort population for g=2: 1.4066696166992188e-05 seconds
# Generation 4 of 100
# Time taken to breed kids for g=3: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=3: 0.0007531642913818359 seconds
# Time taken to evaluate population with C++ evaluator: 0.38065195083618164 seconds
# Time taken to calculate costs for g=3: 0.3844170570373535 seconds
# Lowest cost in generation 3: -987.83
# Time taken to sort population for g=3: 1.621246337890625e-05 seconds
# Generation 5 of 100
# Time taken to breed kids for g=4: 8.869171142578125e-05 seconds
# Time taken to fill random members for g=4: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.377208948135376 seconds
# Time taken to calculate costs for g=4: 0.380932092666626 seconds
# Lowest cost in generation 4: -988.06
# Time taken to sort population for g=4: 1.4781951904296875e-05 seconds
# Generation 6 of 100
# Time taken to breed kids for g=5: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=5: 0.0007228851318359375 seconds
# Time taken to evaluate population with C++ evaluator: 0.3902289867401123 seconds
# Time taken to calculate costs for g=5: 0.3939032554626465 seconds
# Lowest cost in generation 5: -996.22
# Time taken to sort population for g=5: 1.5020370483398438e-05 seconds
# Generation 7 of 100
# Time taken to breed kids for g=6: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=6: 0.0007431507110595703 seconds
# Time taken to evaluate population with C++ evaluator: 0.3811659812927246 seconds
# Time taken to calculate costs for g=6: 0.38476085662841797 seconds
# Lowest cost in generation 6: -996.22
# Time taken to sort population for g=6: 1.6927719116210938e-05 seconds
# Generation 8 of 100
# Time taken to breed kids for g=7: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=7: 0.0007648468017578125 seconds
# Time taken to evaluate population with C++ evaluator: 0.3804628849029541 seconds
# Time taken to calculate costs for g=7: 0.3840351104736328 seconds
# Lowest cost in generation 7: -996.22
# Time taken to sort population for g=7: 1.430511474609375e-05 seconds
# Generation 9 of 100
# Time taken to breed kids for g=8: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=8: 0.0007197856903076172 seconds
# Time taken to evaluate population with C++ evaluator: 0.38327622413635254 seconds
# Time taken to calculate costs for g=8: 0.38681888580322266 seconds
# Lowest cost in generation 8: -996.22
# Time taken to sort population for g=8: 1.2874603271484375e-05 seconds
# Generation 10 of 100
# Time taken to breed kids for g=9: 8.392333984375e-05 seconds
# Time taken to fill random members for g=9: 0.0007302761077880859 seconds
# Time taken to evaluate population with C++ evaluator: 0.37843918800354004 seconds
# Time taken to calculate costs for g=9: 0.3820328712463379 seconds
# Lowest cost in generation 9: -997.27
# Time taken to sort population for g=9: 1.4066696166992188e-05 seconds
# Generation 11 of 100
# Time taken to breed kids for g=10: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=10: 0.0007500648498535156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3867480754852295 seconds
# Time taken to calculate costs for g=10: 0.39040684700012207 seconds
# Lowest cost in generation 10: -997.27
# Time taken to sort population for g=10: 1.4066696166992188e-05 seconds
# Generation 12 of 100
# Time taken to breed kids for g=11: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=11: 0.0007221698760986328 seconds
# Time taken to evaluate population with C++ evaluator: 0.37948107719421387 seconds
# Time taken to calculate costs for g=11: 0.38305115699768066 seconds
# Lowest cost in generation 11: -997.27
# Time taken to sort population for g=11: 1.4066696166992188e-05 seconds
# Generation 13 of 100
# Time taken to breed kids for g=12: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=12: 0.0007889270782470703 seconds
# Time taken to evaluate population with C++ evaluator: 0.37894606590270996 seconds
# Time taken to calculate costs for g=12: 0.38248705863952637 seconds
# Lowest cost in generation 12: -997.27
# Time taken to sort population for g=12: 1.52587890625e-05 seconds
# Generation 14 of 100
# Time taken to breed kids for g=13: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=13: 0.0007238388061523438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3847951889038086 seconds
# Time taken to calculate costs for g=13: 0.38834524154663086 seconds
# Lowest cost in generation 13: -997.27
# Time taken to sort population for g=13: 1.3113021850585938e-05 seconds
# Generation 15 of 100
# Time taken to breed kids for g=14: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=14: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3872108459472656 seconds
# Time taken to calculate costs for g=14: 0.39084315299987793 seconds
# Lowest cost in generation 14: -997.27
# Time taken to sort population for g=14: 1.4066696166992188e-05 seconds
# Generation 16 of 100
# Time taken to breed kids for g=15: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=15: 0.0007550716400146484 seconds
# Time taken to evaluate population with C++ evaluator: 0.39027905464172363 seconds
# Time taken to calculate costs for g=15: 0.3939828872680664 seconds
# Lowest cost in generation 15: -997.27
# Time taken to sort population for g=15: 1.5974044799804688e-05 seconds
# Generation 17 of 100
# Time taken to breed kids for g=16: 0.00012302398681640625 seconds
# Time taken to fill random members for g=16: 0.0007398128509521484 seconds
# Time taken to evaluate population with C++ evaluator: 0.3825840950012207 seconds
# Time taken to calculate costs for g=16: 0.3861069679260254 seconds
# Lowest cost in generation 16: -998.10
# Time taken to sort population for g=16: 1.5020370483398438e-05 seconds
# Generation 18 of 100
# Time taken to breed kids for g=17: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=17: 0.0007507801055908203 seconds
# Time taken to evaluate population with C++ evaluator: 0.38440799713134766 seconds
# Time taken to calculate costs for g=17: 0.388153076171875 seconds
# Lowest cost in generation 17: -998.10
# Time taken to sort population for g=17: 1.3828277587890625e-05 seconds
# Generation 19 of 100
# Time taken to breed kids for g=18: 8.392333984375e-05 seconds
# Time taken to fill random members for g=18: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3813178539276123 seconds
# Time taken to calculate costs for g=18: 0.38500213623046875 seconds
# Lowest cost in generation 18: -998.10
# Time taken to sort population for g=18: 1.1920928955078125e-05 seconds
# Generation 20 of 100
# Time taken to breed kids for g=19: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=19: 0.0008471012115478516 seconds
# Time taken to evaluate population with C++ evaluator: 0.384411096572876 seconds
# Time taken to calculate costs for g=19: 0.38798093795776367 seconds
# Lowest cost in generation 19: -998.10
# Time taken to sort population for g=19: 1.5735626220703125e-05 seconds
# Generation 21 of 100
# Time taken to breed kids for g=20: 9.322166442871094e-05 seconds
# Time taken to fill random members for g=20: 0.0007479190826416016 seconds
# Time taken to evaluate population with C++ evaluator: 0.3894689083099365 seconds
# Time taken to calculate costs for g=20: 0.3930497169494629 seconds
# Lowest cost in generation 20: -998.10
# Time taken to sort population for g=20: 5.412101745605469e-05 seconds
# Generation 22 of 100
# Time taken to breed kids for g=21: 0.00010323524475097656 seconds
# Time taken to fill random members for g=21: 0.0007996559143066406 seconds
# Time taken to evaluate population with C++ evaluator: 0.38205385208129883 seconds
# Time taken to calculate costs for g=21: 0.38597989082336426 seconds
# Lowest cost in generation 21: -998.10
# Time taken to sort population for g=21: 1.3828277587890625e-05 seconds
# Generation 23 of 100
# Time taken to breed kids for g=22: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=22: 0.0007631778717041016 seconds
# Time taken to evaluate population with C++ evaluator: 0.39391207695007324 seconds
# Time taken to calculate costs for g=22: 0.39740490913391113 seconds
# Lowest cost in generation 22: -998.10
# Time taken to sort population for g=22: 1.4066696166992188e-05 seconds
# Generation 24 of 100
# Time taken to breed kids for g=23: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=23: 0.0007722377777099609 seconds
# Time taken to evaluate population with C++ evaluator: 0.38652873039245605 seconds
# Time taken to calculate costs for g=23: 0.3902170658111572 seconds
# Lowest cost in generation 23: -998.10
# Time taken to sort population for g=23: 1.3113021850585938e-05 seconds
# Generation 25 of 100
# Time taken to breed kids for g=24: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=24: 0.0007638931274414062 seconds
# Time taken to evaluate population with C++ evaluator: 0.3839569091796875 seconds
# Time taken to calculate costs for g=24: 0.38765406608581543 seconds
# Lowest cost in generation 24: -998.10
# Time taken to sort population for g=24: 2.4080276489257812e-05 seconds
# Generation 26 of 100
# Time taken to breed kids for g=25: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=25: 0.00074005126953125 seconds
# Time taken to evaluate population with C++ evaluator: 0.38085198402404785 seconds
# Time taken to calculate costs for g=25: 0.384537935256958 seconds
# Lowest cost in generation 25: -998.10
# Time taken to sort population for g=25: 1.3113021850585938e-05 seconds
# Generation 27 of 100
# Time taken to breed kids for g=26: 8.392333984375e-05 seconds
# Time taken to fill random members for g=26: 0.0007410049438476562 seconds
# Time taken to evaluate population with C++ evaluator: 0.3806641101837158 seconds
# Time taken to calculate costs for g=26: 0.38413381576538086 seconds
# Lowest cost in generation 26: -998.10
# Time taken to sort population for g=26: 1.4066696166992188e-05 seconds
# Generation 28 of 100
# Time taken to breed kids for g=27: 8.678436279296875e-05 seconds
# Time taken to fill random members for g=27: 0.0007398128509521484 seconds
# Time taken to evaluate population with C++ evaluator: 0.3835761547088623 seconds
# Time taken to calculate costs for g=27: 0.38727617263793945 seconds
# Lowest cost in generation 27: -998.10
# Time taken to sort population for g=27: 4.1961669921875e-05 seconds
# Generation 29 of 100
# Time taken to breed kids for g=28: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=28: 0.0007729530334472656 seconds
# Time taken to evaluate population with C++ evaluator: 0.42191195487976074 seconds
# Time taken to calculate costs for g=28: 0.4255390167236328 seconds
# Lowest cost in generation 28: -998.10
# Time taken to sort population for g=28: 1.6927719116210938e-05 seconds
# Generation 30 of 100
# Time taken to breed kids for g=29: 9.655952453613281e-05 seconds
# Time taken to fill random members for g=29: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3881521224975586 seconds
# Time taken to calculate costs for g=29: 0.3919508457183838 seconds
# Lowest cost in generation 29: -998.10
# Time taken to sort population for g=29: 1.4066696166992188e-05 seconds
# Generation 31 of 100
# Time taken to breed kids for g=30: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=30: 0.0007379055023193359 seconds
# Time taken to evaluate population with C++ evaluator: 0.3834669589996338 seconds
# Time taken to calculate costs for g=30: 0.3871190547943115 seconds
# Lowest cost in generation 30: -998.10
# Time taken to sort population for g=30: 1.4066696166992188e-05 seconds
# Generation 32 of 100
# Time taken to breed kids for g=31: 9.799003601074219e-05 seconds
# Time taken to fill random members for g=31: 0.0007319450378417969 seconds
# Time taken to evaluate population with C++ evaluator: 0.38119006156921387 seconds
# Time taken to calculate costs for g=31: 0.38485121726989746 seconds
# Lowest cost in generation 31: -998.10
# Time taken to sort population for g=31: 1.3113021850585938e-05 seconds
# Generation 33 of 100
# Time taken to breed kids for g=32: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=32: 0.0007419586181640625 seconds
# Time taken to evaluate population with C++ evaluator: 0.38960909843444824 seconds
# Time taken to calculate costs for g=32: 0.3931090831756592 seconds
# Lowest cost in generation 32: -998.10
# Time taken to sort population for g=32: 1.4066696166992188e-05 seconds
# Generation 34 of 100
# Time taken to breed kids for g=33: 8.559226989746094e-05 seconds
# Time taken to fill random members for g=33: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.40227317810058594 seconds
# Time taken to calculate costs for g=33: 0.4060816764831543 seconds
# Lowest cost in generation 33: -998.10
# Time taken to sort population for g=33: 1.2874603271484375e-05 seconds
# Generation 35 of 100
# Time taken to breed kids for g=34: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=34: 0.0007569789886474609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3836479187011719 seconds
# Time taken to calculate costs for g=34: 0.3872089385986328 seconds
# Lowest cost in generation 34: -998.10
# Time taken to sort population for g=34: 1.4066696166992188e-05 seconds
# Generation 36 of 100
# Time taken to breed kids for g=35: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=35: 0.0007650852203369141 seconds
# Time taken to evaluate population with C++ evaluator: 0.38201379776000977 seconds
# Time taken to calculate costs for g=35: 0.38552188873291016 seconds
# Lowest cost in generation 35: -998.10
# Time taken to sort population for g=35: 1.2874603271484375e-05 seconds
# Generation 37 of 100
# Time taken to breed kids for g=36: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=36: 0.0007379055023193359 seconds
# Time taken to evaluate population with C++ evaluator: 0.3836402893066406 seconds
# Time taken to calculate costs for g=36: 0.3873860836029053 seconds
# Lowest cost in generation 36: -998.10
# Time taken to sort population for g=36: 1.3828277587890625e-05 seconds
# Generation 38 of 100
# Time taken to breed kids for g=37: 9.226799011230469e-05 seconds
# Time taken to fill random members for g=37: 0.0008170604705810547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3866689205169678 seconds
# Time taken to calculate costs for g=37: 0.3904290199279785 seconds
# Lowest cost in generation 37: -998.10
# Time taken to sort population for g=37: 2.2172927856445312e-05 seconds
# Generation 39 of 100
# Time taken to breed kids for g=38: 9.131431579589844e-05 seconds
# Time taken to fill random members for g=38: 0.0007600784301757812 seconds
# Time taken to evaluate population with C++ evaluator: 0.38443994522094727 seconds
# Time taken to calculate costs for g=38: 0.38802289962768555 seconds
# Lowest cost in generation 38: -998.10
# Time taken to sort population for g=38: 1.4066696166992188e-05 seconds
# Generation 40 of 100
# Time taken to breed kids for g=39: 9.584426879882812e-05 seconds
# Time taken to fill random members for g=39: 0.0007610321044921875 seconds
# Time taken to evaluate population with C++ evaluator: 0.383817195892334 seconds
# Time taken to calculate costs for g=39: 0.3876180648803711 seconds
# Lowest cost in generation 39: -998.10
# Time taken to sort population for g=39: 1.4066696166992188e-05 seconds
# Generation 41 of 100
# Time taken to breed kids for g=40: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=40: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.38358402252197266 seconds
# Time taken to calculate costs for g=40: 0.38721632957458496 seconds
# Lowest cost in generation 40: -998.10
# Time taken to sort population for g=40: 1.3828277587890625e-05 seconds
# Generation 42 of 100
# Time taken to breed kids for g=41: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=41: 0.0007519721984863281 seconds
# Time taken to evaluate population with C++ evaluator: 0.3843660354614258 seconds
# Time taken to calculate costs for g=41: 0.38810110092163086 seconds
# Lowest cost in generation 41: -998.10
# Time taken to sort population for g=41: 1.2874603271484375e-05 seconds
# Generation 43 of 100
# Time taken to breed kids for g=42: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=42: 0.0007741451263427734 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868081569671631 seconds
# Time taken to calculate costs for g=42: 0.39044880867004395 seconds
# Lowest cost in generation 42: -998.10
# Time taken to sort population for g=42: 1.5020370483398438e-05 seconds
# Generation 44 of 100
# Time taken to breed kids for g=43: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=43: 0.0007722377777099609 seconds
# Time taken to evaluate population with C++ evaluator: 0.38851094245910645 seconds
# Time taken to calculate costs for g=43: 0.3920738697052002 seconds
# Lowest cost in generation 43: -998.10
# Time taken to sort population for g=43: 1.4066696166992188e-05 seconds
# Generation 45 of 100
# Time taken to breed kids for g=44: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=44: 0.0007460117340087891 seconds
# Time taken to evaluate population with C++ evaluator: 0.3839278221130371 seconds
# Time taken to calculate costs for g=44: 0.3875746726989746 seconds
# Lowest cost in generation 44: -998.10
# Time taken to sort population for g=44: 1.4066696166992188e-05 seconds
# Generation 46 of 100
# Time taken to breed kids for g=45: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=45: 0.0007691383361816406 seconds
# Time taken to evaluate population with C++ evaluator: 0.3822488784790039 seconds
# Time taken to calculate costs for g=45: 0.3858461380004883 seconds
# Lowest cost in generation 45: -998.10
# Time taken to sort population for g=45: 1.4066696166992188e-05 seconds
# Generation 47 of 100
# Time taken to breed kids for g=46: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=46: 0.0007731914520263672 seconds
# Time taken to evaluate population with C++ evaluator: 0.38749098777770996 seconds
# Time taken to calculate costs for g=46: 0.3911571502685547 seconds
# Lowest cost in generation 46: -998.10
# Time taken to sort population for g=46: 1.3828277587890625e-05 seconds
# Generation 48 of 100
# Time taken to breed kids for g=47: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=47: 0.0007340908050537109 seconds
# Time taken to evaluate population with C++ evaluator: 0.3836519718170166 seconds
# Time taken to calculate costs for g=47: 0.3872041702270508 seconds
# Lowest cost in generation 47: -998.10
# Time taken to sort population for g=47: 1.52587890625e-05 seconds
# Generation 49 of 100
# Time taken to breed kids for g=48: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=48: 0.0007538795471191406 seconds
# Time taken to evaluate population with C++ evaluator: 0.3845350742340088 seconds
# Time taken to calculate costs for g=48: 0.3882298469543457 seconds
# Lowest cost in generation 48: -998.10
# Time taken to sort population for g=48: 1.4066696166992188e-05 seconds
# Generation 50 of 100
# Time taken to breed kids for g=49: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=49: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3822951316833496 seconds
# Time taken to calculate costs for g=49: 0.3858602046966553 seconds
# Lowest cost in generation 49: -998.10
# Time taken to sort population for g=49: 1.4066696166992188e-05 seconds
# Generation 51 of 100
# Time taken to breed kids for g=50: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=50: 0.0007290840148925781 seconds
# Time taken to evaluate population with C++ evaluator: 0.38121604919433594 seconds
# Time taken to calculate costs for g=50: 0.38487982749938965 seconds
# Lowest cost in generation 50: -998.10
# Time taken to sort population for g=50: 1.3828277587890625e-05 seconds
# Generation 52 of 100
# Time taken to breed kids for g=51: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=51: 0.0007622241973876953 seconds
# Time taken to evaluate population with C++ evaluator: 0.38542795181274414 seconds
# Time taken to calculate costs for g=51: 0.3891291618347168 seconds
# Lowest cost in generation 51: -998.10
# Time taken to sort population for g=51: 1.2874603271484375e-05 seconds
# Generation 53 of 100
# Time taken to breed kids for g=52: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=52: 0.0007748603820800781 seconds
# Time taken to evaluate population with C++ evaluator: 0.38242006301879883 seconds
# Time taken to calculate costs for g=52: 0.3859739303588867 seconds
# Lowest cost in generation 52: -998.10
# Time taken to sort population for g=52: 1.3113021850585938e-05 seconds
# Generation 54 of 100
# Time taken to breed kids for g=53: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=53: 0.0007739067077636719 seconds
# Time taken to evaluate population with C++ evaluator: 0.3843350410461426 seconds
# Time taken to calculate costs for g=53: 0.38799524307250977 seconds
# Lowest cost in generation 53: -998.10
# Time taken to sort population for g=53: 1.2874603271484375e-05 seconds
# Generation 55 of 100
# Time taken to breed kids for g=54: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=54: 0.0007519721984863281 seconds
# Time taken to evaluate population with C++ evaluator: 0.3829219341278076 seconds
# Time taken to calculate costs for g=54: 0.3863561153411865 seconds
# Lowest cost in generation 54: -998.10
# Time taken to sort population for g=54: 1.3113021850585938e-05 seconds
# Generation 56 of 100
# Time taken to breed kids for g=55: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=55: 0.0007948875427246094 seconds
# Time taken to evaluate population with C++ evaluator: 0.38367795944213867 seconds
# Time taken to calculate costs for g=55: 0.3872520923614502 seconds
# Lowest cost in generation 55: -998.10
# Time taken to sort population for g=55: 1.3113021850585938e-05 seconds
# Generation 57 of 100
# Time taken to breed kids for g=56: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=56: 0.0007519721984863281 seconds
# Time taken to evaluate population with C++ evaluator: 0.3862478733062744 seconds
# Time taken to calculate costs for g=56: 0.389815092086792 seconds
# Lowest cost in generation 56: -998.10
# Time taken to sort population for g=56: 1.3113021850585938e-05 seconds
# Generation 58 of 100
# Time taken to breed kids for g=57: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=57: 0.0007269382476806641 seconds
# Time taken to evaluate population with C++ evaluator: 0.384030818939209 seconds
# Time taken to calculate costs for g=57: 0.3876826763153076 seconds
# Lowest cost in generation 57: -998.10
# Time taken to sort population for g=57: 1.1920928955078125e-05 seconds
# Generation 59 of 100
# Time taken to breed kids for g=58: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=58: 0.00080108642578125 seconds
# Time taken to evaluate population with C++ evaluator: 0.3864271640777588 seconds
# Time taken to calculate costs for g=58: 0.3899528980255127 seconds
# Lowest cost in generation 58: -998.10
# Time taken to sort population for g=58: 1.2874603271484375e-05 seconds
# Generation 60 of 100
# Time taken to breed kids for g=59: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=59: 0.0007610321044921875 seconds
# Time taken to evaluate population with C++ evaluator: 0.3828141689300537 seconds
# Time taken to calculate costs for g=59: 0.3863999843597412 seconds
# Lowest cost in generation 59: -998.10
# Time taken to sort population for g=59: 1.4066696166992188e-05 seconds
# Generation 61 of 100
# Time taken to breed kids for g=60: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=60: 0.0007450580596923828 seconds
# Time taken to evaluate population with C++ evaluator: 0.385761022567749 seconds
# Time taken to calculate costs for g=60: 0.3893311023712158 seconds
# Lowest cost in generation 60: -998.10
# Time taken to sort population for g=60: 1.4066696166992188e-05 seconds
# Generation 62 of 100
# Time taken to breed kids for g=61: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=61: 0.0007319450378417969 seconds
# Time taken to evaluate population with C++ evaluator: 0.38461804389953613 seconds
# Time taken to calculate costs for g=61: 0.38806676864624023 seconds
# Lowest cost in generation 61: -998.10
# Time taken to sort population for g=61: 1.4066696166992188e-05 seconds
# Generation 63 of 100
# Time taken to breed kids for g=62: 8.392333984375e-05 seconds
# Time taken to fill random members for g=62: 0.0007750988006591797 seconds
# Time taken to evaluate population with C++ evaluator: 0.38532400131225586 seconds
# Time taken to calculate costs for g=62: 0.38896989822387695 seconds
# Lowest cost in generation 62: -998.10
# Time taken to sort population for g=62: 1.3113021850585938e-05 seconds
# Generation 64 of 100
# Time taken to breed kids for g=63: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=63: 0.0007319450378417969 seconds
# Time taken to evaluate population with C++ evaluator: 0.38272595405578613 seconds
# Time taken to calculate costs for g=63: 0.38635993003845215 seconds
# Lowest cost in generation 63: -998.10
# Time taken to sort population for g=63: 1.4066696166992188e-05 seconds
# Generation 65 of 100
# Time taken to breed kids for g=64: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=64: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.38393187522888184 seconds
# Time taken to calculate costs for g=64: 0.3874950408935547 seconds
# Lowest cost in generation 64: -998.10
# Time taken to sort population for g=64: 1.4066696166992188e-05 seconds
# Generation 66 of 100
# Time taken to breed kids for g=65: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=65: 0.0007376670837402344 seconds
# Time taken to evaluate population with C++ evaluator: 0.38578081130981445 seconds
# Time taken to calculate costs for g=65: 0.38938093185424805 seconds
# Lowest cost in generation 65: -998.10
# Time taken to sort population for g=65: 1.5020370483398438e-05 seconds
# Generation 67 of 100
# Time taken to breed kids for g=66: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=66: 0.0007238388061523438 seconds
# Time taken to evaluate population with C++ evaluator: 0.38496994972229004 seconds
# Time taken to calculate costs for g=66: 0.38849782943725586 seconds
# Lowest cost in generation 66: -998.10
# Time taken to sort population for g=66: 1.3828277587890625e-05 seconds
# Generation 68 of 100
# Time taken to breed kids for g=67: 8.392333984375e-05 seconds
# Time taken to fill random members for g=67: 0.0008559226989746094 seconds
# Time taken to evaluate population with C++ evaluator: 0.3883059024810791 seconds
# Time taken to calculate costs for g=67: 0.3918321132659912 seconds
# Lowest cost in generation 67: -998.10
# Time taken to sort population for g=67: 1.3828277587890625e-05 seconds
# Generation 69 of 100
# Time taken to breed kids for g=68: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=68: 0.0009059906005859375 seconds
# Time taken to evaluate population with C++ evaluator: 0.39046502113342285 seconds
# Time taken to calculate costs for g=68: 0.3939800262451172 seconds
# Lowest cost in generation 68: -998.10
# Time taken to sort population for g=68: 1.3828277587890625e-05 seconds
# Generation 70 of 100
# Time taken to breed kids for g=69: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=69: 0.0007929801940917969 seconds
# Time taken to evaluate population with C++ evaluator: 0.3873112201690674 seconds
# Time taken to calculate costs for g=69: 0.39080810546875 seconds
# Lowest cost in generation 69: -998.10
# Time taken to sort population for g=69: 1.4066696166992188e-05 seconds
# Generation 71 of 100
# Time taken to breed kids for g=70: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=70: 0.0007460117340087891 seconds
# Time taken to evaluate population with C++ evaluator: 0.38640522956848145 seconds
# Time taken to calculate costs for g=70: 0.3900899887084961 seconds
# Lowest cost in generation 70: -998.10
# Time taken to sort population for g=70: 1.4066696166992188e-05 seconds
# Generation 72 of 100
# Time taken to breed kids for g=71: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=71: 0.0007569789886474609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3853731155395508 seconds
# Time taken to calculate costs for g=71: 0.3890500068664551 seconds
# Lowest cost in generation 71: -998.10
# Time taken to sort population for g=71: 1.2874603271484375e-05 seconds
# Generation 73 of 100
# Time taken to breed kids for g=72: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=72: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3854329586029053 seconds
# Time taken to calculate costs for g=72: 0.3890700340270996 seconds
# Lowest cost in generation 72: -998.10
# Time taken to sort population for g=72: 1.3828277587890625e-05 seconds
# Generation 74 of 100
# Time taken to breed kids for g=73: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=73: 0.0008749961853027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3875260353088379 seconds
# Time taken to calculate costs for g=73: 0.39114880561828613 seconds
# Lowest cost in generation 73: -998.10
# Time taken to sort population for g=73: 1.3828277587890625e-05 seconds
# Generation 75 of 100
# Time taken to breed kids for g=74: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=74: 0.0007729530334472656 seconds
# Time taken to evaluate population with C++ evaluator: 0.38666582107543945 seconds
# Time taken to calculate costs for g=74: 0.3903369903564453 seconds
# Lowest cost in generation 74: -998.10
# Time taken to sort population for g=74: 1.3113021850585938e-05 seconds
# Generation 76 of 100
# Time taken to breed kids for g=75: 8.20159912109375e-05 seconds
# Time taken to fill random members for g=75: 0.0007328987121582031 seconds
# Time taken to evaluate population with C++ evaluator: 0.38843512535095215 seconds
# Time taken to calculate costs for g=75: 0.3919360637664795 seconds
# Lowest cost in generation 75: -998.10
# Time taken to sort population for g=75: 1.5974044799804688e-05 seconds
# Generation 77 of 100
# Time taken to breed kids for g=76: 0.00010013580322265625 seconds
# Time taken to fill random members for g=76: 0.0008130073547363281 seconds
# Time taken to evaluate population with C++ evaluator: 0.3844149112701416 seconds
# Time taken to calculate costs for g=76: 0.3879518508911133 seconds
# Lowest cost in generation 76: -998.10
# Time taken to sort population for g=76: 1.5020370483398438e-05 seconds
# Generation 78 of 100
# Time taken to breed kids for g=77: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=77: 0.0007498264312744141 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868570327758789 seconds
# Time taken to calculate costs for g=77: 0.3903391361236572 seconds
# Lowest cost in generation 77: -998.10
# Time taken to sort population for g=77: 1.4066696166992188e-05 seconds
# Generation 79 of 100
# Time taken to breed kids for g=78: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=78: 0.0007348060607910156 seconds
# Time taken to evaluate population with C++ evaluator: 0.38661813735961914 seconds
# Time taken to calculate costs for g=78: 0.3901681900024414 seconds
# Lowest cost in generation 78: -998.10
# Time taken to sort population for g=78: 1.3113021850585938e-05 seconds
# Generation 80 of 100
# Time taken to breed kids for g=79: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=79: 0.0007758140563964844 seconds
# Time taken to evaluate population with C++ evaluator: 0.3839700222015381 seconds
# Time taken to calculate costs for g=79: 0.38776683807373047 seconds
# Lowest cost in generation 79: -998.10
# Time taken to sort population for g=79: 1.4066696166992188e-05 seconds
# Generation 81 of 100
# Time taken to breed kids for g=80: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=80: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.38103461265563965 seconds
# Time taken to calculate costs for g=80: 0.38452982902526855 seconds
# Lowest cost in generation 80: -998.10
# Time taken to sort population for g=80: 1.4066696166992188e-05 seconds
# Generation 82 of 100
# Time taken to breed kids for g=81: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=81: 0.0007328987121582031 seconds
# Time taken to evaluate population with C++ evaluator: 0.3863251209259033 seconds
# Time taken to calculate costs for g=81: 0.3899240493774414 seconds
# Lowest cost in generation 81: -998.10
# Time taken to sort population for g=81: 1.3828277587890625e-05 seconds
# Generation 83 of 100
# Time taken to breed kids for g=82: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=82: 0.0007688999176025391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868281841278076 seconds
# Time taken to calculate costs for g=82: 0.390484094619751 seconds
# Lowest cost in generation 82: -998.10
# Time taken to sort population for g=82: 1.3113021850585938e-05 seconds
# Generation 84 of 100
# Time taken to breed kids for g=83: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=83: 0.0007648468017578125 seconds
# Time taken to evaluate population with C++ evaluator: 0.3844022750854492 seconds
# Time taken to calculate costs for g=83: 0.38797807693481445 seconds
# Lowest cost in generation 83: -998.10
# Time taken to sort population for g=83: 1.4781951904296875e-05 seconds
# Generation 85 of 100
# Time taken to breed kids for g=84: 8.392333984375e-05 seconds
# Time taken to fill random members for g=84: 0.0007841587066650391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3883378505706787 seconds
# Time taken to calculate costs for g=84: 0.3919038772583008 seconds
# Lowest cost in generation 84: -998.10
# Time taken to sort population for g=84: 1.4066696166992188e-05 seconds
# Generation 86 of 100
# Time taken to breed kids for g=85: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=85: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.38393592834472656 seconds
# Time taken to calculate costs for g=85: 0.38754796981811523 seconds
# Lowest cost in generation 85: -998.10
# Time taken to sort population for g=85: 1.52587890625e-05 seconds
# Generation 87 of 100
# Time taken to breed kids for g=86: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=86: 0.0008127689361572266 seconds
# Time taken to evaluate population with C++ evaluator: 0.3861989974975586 seconds
# Time taken to calculate costs for g=86: 0.38973498344421387 seconds
# Lowest cost in generation 86: -998.10
# Time taken to sort population for g=86: 1.5020370483398438e-05 seconds
# Generation 88 of 100
# Time taken to breed kids for g=87: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=87: 0.0008060932159423828 seconds
# Time taken to evaluate population with C++ evaluator: 0.3880157470703125 seconds
# Time taken to calculate costs for g=87: 0.39173007011413574 seconds
# Lowest cost in generation 87: -998.10
# Time taken to sort population for g=87: 1.4066696166992188e-05 seconds
# Generation 89 of 100
# Time taken to breed kids for g=88: 8.082389831542969e-05 seconds
# Time taken to fill random members for g=88: 0.0007569789886474609 seconds
# Time taken to evaluate population with C++ evaluator: 0.38397908210754395 seconds
# Time taken to calculate costs for g=88: 0.38747310638427734 seconds
# Lowest cost in generation 88: -998.10
# Time taken to sort population for g=88: 1.3113021850585938e-05 seconds
# Generation 90 of 100
# Time taken to breed kids for g=89: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=89: 0.0007648468017578125 seconds
# Time taken to evaluate population with C++ evaluator: 0.38434672355651855 seconds
# Time taken to calculate costs for g=89: 0.387923002243042 seconds
# Lowest cost in generation 89: -998.10
# Time taken to sort population for g=89: 1.4066696166992188e-05 seconds
# Generation 91 of 100
# Time taken to breed kids for g=90: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=90: 0.0007338523864746094 seconds
# Time taken to evaluate population with C++ evaluator: 0.38606691360473633 seconds
# Time taken to calculate costs for g=90: 0.3895590305328369 seconds
# Lowest cost in generation 90: -998.10
# Time taken to sort population for g=90: 1.4066696166992188e-05 seconds
# Generation 92 of 100
# Time taken to breed kids for g=91: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=91: 0.0007579326629638672 seconds
# Time taken to evaluate population with C++ evaluator: 0.3840599060058594 seconds
# Time taken to calculate costs for g=91: 0.3877880573272705 seconds
# Lowest cost in generation 91: -998.10
# Time taken to sort population for g=91: 1.430511474609375e-05 seconds
# Generation 93 of 100
# Time taken to breed kids for g=92: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=92: 0.0007197856903076172 seconds
# Time taken to evaluate population with C++ evaluator: 0.38622212409973145 seconds
# Time taken to calculate costs for g=92: 0.38982391357421875 seconds
# Lowest cost in generation 92: -998.10
# Time taken to sort population for g=92: 1.4066696166992188e-05 seconds
# Generation 94 of 100
# Time taken to breed kids for g=93: 8.678436279296875e-05 seconds
# Time taken to fill random members for g=93: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.38512516021728516 seconds
# Time taken to calculate costs for g=93: 0.38873720169067383 seconds
# Lowest cost in generation 93: -998.10
# Time taken to sort population for g=93: 1.3828277587890625e-05 seconds
# Generation 95 of 100
# Time taken to breed kids for g=94: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=94: 0.0007908344268798828 seconds
# Time taken to evaluate population with C++ evaluator: 0.3860969543457031 seconds
# Time taken to calculate costs for g=94: 0.3896310329437256 seconds
# Lowest cost in generation 94: -998.10
# Time taken to sort population for g=94: 1.5974044799804688e-05 seconds
# Generation 96 of 100
# Time taken to breed kids for g=95: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=95: 0.0007271766662597656 seconds
# Time taken to evaluate population with C++ evaluator: 0.38786816596984863 seconds
# Time taken to calculate costs for g=95: 0.39144015312194824 seconds
# Lowest cost in generation 95: -998.10
# Time taken to sort population for g=95: 1.3828277587890625e-05 seconds
# Generation 97 of 100
# Time taken to breed kids for g=96: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=96: 0.0008139610290527344 seconds
# Time taken to evaluate population with C++ evaluator: 0.42777132987976074 seconds
# Time taken to calculate costs for g=96: 0.431535005569458 seconds
# Lowest cost in generation 96: -998.10
# Time taken to sort population for g=96: 7.891654968261719e-05 seconds
# Generation 98 of 100
# Time taken to breed kids for g=97: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=97: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.39127397537231445 seconds
# Time taken to calculate costs for g=97: 0.3950068950653076 seconds
# Lowest cost in generation 97: -998.10
# Time taken to sort population for g=97: 1.4066696166992188e-05 seconds
# Generation 99 of 100
# Time taken to breed kids for g=98: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=98: 0.0007541179656982422 seconds
# Time taken to evaluate population with C++ evaluator: 0.3890681266784668 seconds
# Time taken to calculate costs for g=98: 0.39345693588256836 seconds
# Lowest cost in generation 98: -998.10
# Time taken to sort population for g=98: 1.5020370483398438e-05 seconds
# Generation 100 of 100
# Time taken to breed kids for g=99: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=99: 0.000759124755859375 seconds
# Time taken to evaluate population with C++ evaluator: 0.3898899555206299 seconds
# Time taken to calculate costs for g=99: 0.39339113235473633 seconds
# Lowest cost in generation 99: -998.10
# Time taken to sort population for g=99: 1.3113021850585938e-05 seconds

# %%
with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "rb") as f:
    result = pickle.load(f)

# %%
[unique_values, unique_costs] = result.final_population.get_unique_designs()

# %%
unique_values_df = pd.DataFrame({
    'Irrigation frequency (every X hours)': unique_values[:, 0],
    'Irrigation amount (in)':               unique_values[:, 1],
    'Fertilizer frequency (every X hours)': unique_values[:, 2],
    'Fertilizer amount (lb)':               unique_values[:, 3],
    'Cost ($)':                             unique_costs,
    'Revenue ($)':                          -unique_costs,
})
unique_values_df.to_csv(f'ga_parallel_results/unique_values_costs_results/ga_parallel_result_unique_values_and_costs_{input_key}.csv', index=False)

# %%
#result.print_table_of_best_designs()

# %%
result.plot_optimization_results()

# %%
min(unique_costs)
# Out:
# np.float64(-876.0366986295974)

# %%
# Import necessary modules
import numpy as np
import os
import pandas as pd
import pickle
import sys

here = os.path.dirname(os.path.abspath("__file__"))
project_root = os.path.abspath(os.path.join(here, '../../'))
sys.path.insert(0, project_root)

from core.ga.ga_bounds import DesignSpaceBounds
from core.ga.ga_params import GeneticAlgorithmParams
from core.ga.ga import GeneticAlgorithm

from core.model.model_carrying_capacities import ModelCarryingCapacities
from core.model.model_disturbances import ModelDisturbances
from core.model.model_growth_rates import ModelGrowthRates
from core.model.model_initial_conditions import ModelInitialConditions
from core.model.model_params import ModelParams
from core.model.model_typical_disturbances import ModelTypicalDisturbances
from core.model.model_sensitivities import ModelSensitivities

from ga_member_cpp import Evaluator

# %%
input_key = 1

# %% [markdown]
# ## Model Parameters

# %%
# Set ModelParams (time stepping)
model_params = ModelParams(
    dt               = 1.0,  # hours/step
    simulation_hours = 2900, # hours
    verbose          = True  # for the single simulation
)

# %%
# Set ModelCarryingCapacities
carrying_capacities = ModelCarryingCapacities(
    kh = 3.0,  # m
    kA = 0.65, # m2
    kN = 20,   # number of leaves
    kc = 1000, # number of spikelets
    kP = 0.25  # kg
)

# %%
# Set ModelGrowthRates
growth_rates = ModelGrowthRates(
    ah = 0.01,   # 1/hr
    aA = 0.0105, # 1/hr
    aN = 0.011,  # 1/hr
    ac = 0.01,   # 1/hr
    aP = 0.005   # 1/hr
)

# %%
# Set ModelSensitivities
sensitivities = ModelSensitivities(
    sigma_W = 30,  # hrs
    sigma_F = 300, # hrs
    sigma_T = 30,  # hrs
    sigma_R = 30   # hrs
)

# %%
# Set ModelInitialConditions
initial_conditions = ModelInitialConditions(
    h0=carrying_capacities.kh/model_params.simulation_hours, # m/hr
    A0=carrying_capacities.kA/model_params.simulation_hours, # m2/hr
    N0=carrying_capacities.kN/model_params.simulation_hours, # number/hr
    c0=carrying_capacities.kc/model_params.simulation_hours, # number/hr
    P0=carrying_capacities.kP/model_params.simulation_hours  # kg/hr
)

# %% [markdown]
# ## Design Space

# %%
lower_bounds_dict = {
    "irrigation_frequency":    12, # once every X hours
    "irrigation_amount":       0,  # inches per irrigation
    "fertilization_frequency": 24, # once every X hours (once a day)
    "fertilization_amount":    0   # pounds per fertilization
}
lower_bounds = np.array([value for key, value in lower_bounds_dict.items()])

# %%
upper_bounds_dict = {
    "irrigation_frequency":    2900,  # once a season
    "irrigation_amount":       10,    # inches per irrigation
    "fertilization_frequency": 2900,  # once a season
    "fertilization_amount":    700    # pounds per fertilization
}
upper_bounds = np.array([value for key, value in upper_bounds_dict.items()])

# %%
# Set DesignSpaceBounds
bounds = DesignSpaceBounds(
    lower_bounds=lower_bounds,
    upper_bounds=upper_bounds
)

# %% [markdown]
# ## Genetic Algorithm Parameters

# %%
# Genetic algorithm style inputs
ga_params = GeneticAlgorithmParams(
    num_parents     = 16,  # number of design strings to breed
    num_kids        = 16,  # number of offspring design strings
    num_generations = 100, # number of generations
    num_members     = 128, # number of simulations per generation
)

# %% [markdown]
# ## Input Disturbances

# %%
# Hourly precipitation, radiation, and temperature from CSV
hourly_input_disturbances = pd.read_csv(
    '../../io/inputs/hourly_prcp_rad_temp_iowa.csv'
)

# %%
# Set ModelDisturbances
input_disturbances = ModelDisturbances(
    precipitation = hourly_input_disturbances['Hourly Precipitation (in)'].to_numpy(),
    radiation     = hourly_input_disturbances['Hourly Radiation (W/m2)'].to_numpy(),
    temperature   = hourly_input_disturbances['Temperature (C)'].to_numpy()
)

# %% [markdown]
# ## Optimal/Typical Values

# %%
default_typical_disturbances = ModelTypicalDisturbances()

typical_disturbances = ModelTypicalDisturbances(
    typical_water       = default_typical_disturbances.typical_water * model_params.dt,
    typical_fertilizer  = default_typical_disturbances.typical_fertilizer * model_params.dt,
    typical_temperature = default_typical_disturbances.typical_temperature * model_params.dt,
    typical_radiation   = default_typical_disturbances.typical_radiation * model_params.dt
)

# %% [markdown]
# ## Single simulation

# %%
# Carla test params
irrigation_frequency = 24 * 7 * 2  # Irrigate once every 336 hours
irrigation_amount    = 0.23        # with 0.23 inches per irrigation (goal is 28 in including precip)
fertilizer_frequency = 24 * 30 * 3 # Fertilize once every 2160 hours
fertilizer_amount    = 175         # with 175 lbs per fertilization (goal is 355 lbs over season)

'''
# Example bad params
irrigation_frequency = 1
irrigation_amount    = 0
fertilizer_frequency = 1
fertilizer_amount    = 0
'''
# Out:
# '\n# Example bad params\nirrigation_frequency = 1\nirrigation_amount    = 0\nfertilizer_frequency = 1\nfertilizer_amount    = 0\n'

# %%
# Construct a single-member population Evaluator
from core.ga.ga_population import Population
population = Population(
    bounds               = bounds,
    ga_params            = ga_params,
    carrying_capacities  = carrying_capacities,
    disturbances         = input_disturbances,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    model_params         = model_params,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities,
    values = np.array([[irrigation_frequency, irrigation_amount, fertilizer_frequency, fertilizer_amount]])
)

# %%
population.set_costs_with_cpp()
cost_cpp = population.costs[0]
print(f"Cost from C++ Evaluator: {cost_cpp}")
# Out:
# Time taken to evaluate population with C++ evaluator: 0.0030689239501953125 seconds
# Cost from C++ Evaluator: -607.4450492586295

# %%
population.set_costs()
cost_py = population.costs[0]
print(f"Cost from Python Evaluator: {cost_py}")
# Out:
# Cost from Python Evaluator: -607.4450492586298

# %%
import time, numpy as np

# 1) context build
t0 = time.perf_counter()
ctx = population._build_sim_context_dict_cpp()
t1 = time.perf_counter()

# 2) evaluator construction
from ga_member_cpp import Evaluator
ev = Evaluator(ctx)
t2 = time.perf_counter()

# 3) evaluation (all 128)
X = np.ascontiguousarray(population.values, dtype=np.float64)  # IMPORTANT
costs = ev.evaluate_population(X)
t3 = time.perf_counter()

print("build ctx:", t1-t0)
print("make eval:", t2-t1)
print("eval pop :", t3-t2)
# Out:
# build ctx: 0.0026207499904558063
# make eval: 0.0015916250413283706
# eval pop : 0.003105666022747755

# %% [markdown]
# ## Genetic Algorithm

# %%
# Set verbose to False for GA runs
model_params.verbose = False

# Create GeneticAlgorithm object from all inputs
GeneticAlgorithm = GeneticAlgorithm(
    bounds               = bounds,
    ga_params            = ga_params,
    model_params         = model_params,
    carrying_capacities  = carrying_capacities,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    disturbances         = input_disturbances,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities
)

# %%
# Run the Genetic Algorithm and save the result

GeneticAlgorithmResult = GeneticAlgorithm.run_with_cpp()

with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "wb") as f:
    pickle.dump(GeneticAlgorithmResult, f)
# Out:
# Time taken to evaluate population with C++ evaluator: 0.3742208480834961 seconds
# Time taken to calculate costs for g=0: 0.37822413444519043 seconds
# Generation 2 of 100
# Time taken to breed kids for g=1: 0.0004851818084716797 seconds
# Time taken to fill random members for g=1: 0.0005719661712646484 seconds
# Time taken to evaluate population with C++ evaluator: 0.37703967094421387 seconds
# Time taken to calculate costs for g=1: 0.3807229995727539 seconds
# Lowest cost in generation 1: -901.71
# Time taken to sort population for g=1: 1.7881393432617188e-05 seconds
# Generation 3 of 100
# Time taken to breed kids for g=2: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=2: 0.0007586479187011719 seconds
# Time taken to evaluate population with C++ evaluator: 0.37744998931884766 seconds
# Time taken to calculate costs for g=2: 0.38117122650146484 seconds
# Lowest cost in generation 2: -915.46
# Time taken to sort population for g=2: 1.3828277587890625e-05 seconds
# Generation 4 of 100
# Time taken to breed kids for g=3: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=3: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.38033413887023926 seconds
# Time taken to calculate costs for g=3: 0.38397908210754395 seconds
# Lowest cost in generation 3: -915.46
# Time taken to sort population for g=3: 1.5974044799804688e-05 seconds
# Generation 5 of 100
# Time taken to breed kids for g=4: 7.700920104980469e-05 seconds
# Time taken to fill random members for g=4: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3800652027130127 seconds
# Time taken to calculate costs for g=4: 0.3839762210845947 seconds
# Lowest cost in generation 4: -922.59
# Time taken to sort population for g=4: 1.4066696166992188e-05 seconds
# Generation 6 of 100
# Time taken to breed kids for g=5: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=5: 0.0007240772247314453 seconds
# Time taken to evaluate population with C++ evaluator: 0.3770747184753418 seconds
# Time taken to calculate costs for g=5: 0.38083815574645996 seconds
# Lowest cost in generation 5: -930.26
# Time taken to sort population for g=5: 1.4066696166992188e-05 seconds
# Generation 7 of 100
# Time taken to breed kids for g=6: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=6: 0.0008237361907958984 seconds
# Time taken to evaluate population with C++ evaluator: 0.37126922607421875 seconds
# Time taken to calculate costs for g=6: 0.375075101852417 seconds
# Lowest cost in generation 6: -930.26
# Time taken to sort population for g=6: 1.2159347534179688e-05 seconds
# Generation 8 of 100
# Time taken to breed kids for g=7: 8.082389831542969e-05 seconds
# Time taken to fill random members for g=7: 0.00074005126953125 seconds
# Time taken to evaluate population with C++ evaluator: 0.37227916717529297 seconds
# Time taken to calculate costs for g=7: 0.3758220672607422 seconds
# Lowest cost in generation 7: -930.26
# Time taken to sort population for g=7: 1.4066696166992188e-05 seconds
# Generation 9 of 100
# Time taken to breed kids for g=8: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=8: 0.0007891654968261719 seconds
# Time taken to evaluate population with C++ evaluator: 0.3717660903930664 seconds
# Time taken to calculate costs for g=8: 0.37528300285339355 seconds
# Lowest cost in generation 8: -930.26
# Time taken to sort population for g=8: 1.3828277587890625e-05 seconds
# Generation 10 of 100
# Time taken to breed kids for g=9: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=9: 0.0007631778717041016 seconds
# Time taken to evaluate population with C++ evaluator: 0.37443995475769043 seconds
# Time taken to calculate costs for g=9: 0.37800073623657227 seconds
# Lowest cost in generation 9: -955.03
# Time taken to sort population for g=9: 1.52587890625e-05 seconds
# Generation 11 of 100
# Time taken to breed kids for g=10: 8.869171142578125e-05 seconds
# Time taken to fill random members for g=10: 0.0008018016815185547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3723721504211426 seconds
# Time taken to calculate costs for g=10: 0.3760509490966797 seconds
# Lowest cost in generation 10: -955.03
# Time taken to sort population for g=10: 1.52587890625e-05 seconds
# Generation 12 of 100
# Time taken to breed kids for g=11: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=11: 0.0007641315460205078 seconds
# Time taken to evaluate population with C++ evaluator: 0.3752470016479492 seconds
# Time taken to calculate costs for g=11: 0.3789379596710205 seconds
# Lowest cost in generation 11: -955.03
# Time taken to sort population for g=11: 1.4066696166992188e-05 seconds
# Generation 13 of 100
# Time taken to breed kids for g=12: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=12: 0.0007879734039306641 seconds
# Time taken to evaluate population with C++ evaluator: 0.37313008308410645 seconds
# Time taken to calculate costs for g=12: 0.3767707347869873 seconds
# Lowest cost in generation 12: -955.03
# Time taken to sort population for g=12: 1.2636184692382812e-05 seconds
# Generation 14 of 100
# Time taken to breed kids for g=13: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=13: 0.0007688999176025391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3763289451599121 seconds
# Time taken to calculate costs for g=13: 0.38008999824523926 seconds
# Lowest cost in generation 13: -955.03
# Time taken to sort population for g=13: 1.3828277587890625e-05 seconds
# Generation 15 of 100
# Time taken to breed kids for g=14: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=14: 0.0007500648498535156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3730008602142334 seconds
# Time taken to calculate costs for g=14: 0.3765289783477783 seconds
# Lowest cost in generation 14: -955.03
# Time taken to sort population for g=14: 1.71661376953125e-05 seconds
# Generation 16 of 100
# Time taken to breed kids for g=15: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=15: 0.000985860824584961 seconds
# Time taken to evaluate population with C++ evaluator: 0.377230167388916 seconds
# Time taken to calculate costs for g=15: 0.38053131103515625 seconds
# Lowest cost in generation 15: -955.03
# Time taken to sort population for g=15: 1.3113021850585938e-05 seconds
# Generation 17 of 100
# Time taken to breed kids for g=16: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=16: 0.0007729530334472656 seconds
# Time taken to evaluate population with C++ evaluator: 0.3726229667663574 seconds
# Time taken to calculate costs for g=16: 0.3763089179992676 seconds
# Lowest cost in generation 16: -955.03
# Time taken to sort population for g=16: 1.4066696166992188e-05 seconds
# Generation 18 of 100
# Time taken to breed kids for g=17: 0.0001227855682373047 seconds
# Time taken to fill random members for g=17: 0.0008058547973632812 seconds
# Time taken to evaluate population with C++ evaluator: 0.37379908561706543 seconds
# Time taken to calculate costs for g=17: 0.377410888671875 seconds
# Lowest cost in generation 17: -955.03
# Time taken to sort population for g=17: 1.52587890625e-05 seconds
# Generation 19 of 100
# Time taken to breed kids for g=18: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=18: 0.0007789134979248047 seconds
# Time taken to evaluate population with C++ evaluator: 0.3805201053619385 seconds
# Time taken to calculate costs for g=18: 0.3840017318725586 seconds
# Lowest cost in generation 18: -955.03
# Time taken to sort population for g=18: 1.3828277587890625e-05 seconds
# Generation 20 of 100
# Time taken to breed kids for g=19: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=19: 0.0007431507110595703 seconds
# Time taken to evaluate population with C++ evaluator: 0.3708059787750244 seconds
# Time taken to calculate costs for g=19: 0.3745880126953125 seconds
# Lowest cost in generation 19: -955.03
# Time taken to sort population for g=19: 1.3828277587890625e-05 seconds
# Generation 21 of 100
# Time taken to breed kids for g=20: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=20: 0.0007410049438476562 seconds
# Time taken to evaluate population with C++ evaluator: 0.3751492500305176 seconds
# Time taken to calculate costs for g=20: 0.3788590431213379 seconds
# Lowest cost in generation 20: -955.03
# Time taken to sort population for g=20: 1.5020370483398438e-05 seconds
# Generation 22 of 100
# Time taken to breed kids for g=21: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=21: 0.0007832050323486328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3727409839630127 seconds
# Time taken to calculate costs for g=21: 0.3763120174407959 seconds
# Lowest cost in generation 21: -955.03
# Time taken to sort population for g=21: 1.4066696166992188e-05 seconds
# Generation 23 of 100
# Time taken to breed kids for g=22: 8.869171142578125e-05 seconds
# Time taken to fill random members for g=22: 0.0007619857788085938 seconds
# Time taken to evaluate population with C++ evaluator: 0.37125706672668457 seconds
# Time taken to calculate costs for g=22: 0.374722957611084 seconds
# Lowest cost in generation 22: -955.03
# Time taken to sort population for g=22: 1.1682510375976562e-05 seconds
# Generation 24 of 100
# Time taken to breed kids for g=23: 8.225440979003906e-05 seconds
# Time taken to fill random members for g=23: 0.0007650852203369141 seconds
# Time taken to evaluate population with C++ evaluator: 0.3814551830291748 seconds
# Time taken to calculate costs for g=23: 0.3850281238555908 seconds
# Lowest cost in generation 23: -955.03
# Time taken to sort population for g=23: 7.581710815429688e-05 seconds
# Generation 25 of 100
# Time taken to breed kids for g=24: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=24: 0.0007250308990478516 seconds
# Time taken to evaluate population with C++ evaluator: 0.3717660903930664 seconds
# Time taken to calculate costs for g=24: 0.37537169456481934 seconds
# Lowest cost in generation 24: -955.03
# Time taken to sort population for g=24: 2.002716064453125e-05 seconds
# Generation 26 of 100
# Time taken to breed kids for g=25: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=25: 0.0007848739624023438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3751561641693115 seconds
# Time taken to calculate costs for g=25: 0.3788750171661377 seconds
# Lowest cost in generation 25: -955.03
# Time taken to sort population for g=25: 1.3113021850585938e-05 seconds
# Generation 27 of 100
# Time taken to breed kids for g=26: 8.869171142578125e-05 seconds
# Time taken to fill random members for g=26: 0.0007951259613037109 seconds
# Time taken to evaluate population with C++ evaluator: 0.3757758140563965 seconds
# Time taken to calculate costs for g=26: 0.37941598892211914 seconds
# Lowest cost in generation 26: -955.03
# Time taken to sort population for g=26: 1.7881393432617188e-05 seconds
# Generation 28 of 100
# Time taken to breed kids for g=27: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=27: 0.0007822513580322266 seconds
# Time taken to evaluate population with C++ evaluator: 0.37400293350219727 seconds
# Time taken to calculate costs for g=27: 0.3775968551635742 seconds
# Lowest cost in generation 27: -955.03
# Time taken to sort population for g=27: 1.3113021850585938e-05 seconds
# Generation 29 of 100
# Time taken to breed kids for g=28: 9.965896606445312e-05 seconds
# Time taken to fill random members for g=28: 0.0008258819580078125 seconds
# Time taken to evaluate population with C++ evaluator: 0.37491393089294434 seconds
# Time taken to calculate costs for g=28: 0.3784172534942627 seconds
# Lowest cost in generation 28: -955.03
# Time taken to sort population for g=28: 1.3113021850585938e-05 seconds
# Generation 30 of 100
# Time taken to breed kids for g=29: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=29: 0.0007841587066650391 seconds
# Time taken to evaluate population with C++ evaluator: 0.37276124954223633 seconds
# Time taken to calculate costs for g=29: 0.3764941692352295 seconds
# Lowest cost in generation 29: -955.03
# Time taken to sort population for g=29: 1.4066696166992188e-05 seconds
# Generation 31 of 100
# Time taken to breed kids for g=30: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=30: 0.0007581710815429688 seconds
# Time taken to evaluate population with C++ evaluator: 0.37376928329467773 seconds
# Time taken to calculate costs for g=30: 0.3771688938140869 seconds
# Lowest cost in generation 30: -955.03
# Time taken to sort population for g=30: 1.2159347534179688e-05 seconds
# Generation 32 of 100
# Time taken to breed kids for g=31: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=31: 0.0007848739624023438 seconds
# Time taken to evaluate population with C++ evaluator: 0.374859094619751 seconds
# Time taken to calculate costs for g=31: 0.37836527824401855 seconds
# Lowest cost in generation 31: -955.03
# Time taken to sort population for g=31: 1.4066696166992188e-05 seconds
# Generation 33 of 100
# Time taken to breed kids for g=32: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=32: 0.0007641315460205078 seconds
# Time taken to evaluate population with C++ evaluator: 0.37550902366638184 seconds
# Time taken to calculate costs for g=32: 0.3791239261627197 seconds
# Lowest cost in generation 32: -955.03
# Time taken to sort population for g=32: 1.5974044799804688e-05 seconds
# Generation 34 of 100
# Time taken to breed kids for g=33: 9.799003601074219e-05 seconds
# Time taken to fill random members for g=33: 0.0007319450378417969 seconds
# Time taken to evaluate population with C++ evaluator: 0.3748972415924072 seconds
# Time taken to calculate costs for g=33: 0.37837862968444824 seconds
# Lowest cost in generation 33: -955.03
# Time taken to sort population for g=33: 1.3113021850585938e-05 seconds
# Generation 35 of 100
# Time taken to breed kids for g=34: 8.726119995117188e-05 seconds
# Time taken to fill random members for g=34: 0.0007810592651367188 seconds
# Time taken to evaluate population with C++ evaluator: 0.3734288215637207 seconds
# Time taken to calculate costs for g=34: 0.37716102600097656 seconds
# Lowest cost in generation 34: -955.03
# Time taken to sort population for g=34: 1.811981201171875e-05 seconds
# Generation 36 of 100
# Time taken to breed kids for g=35: 9.870529174804688e-05 seconds
# Time taken to fill random members for g=35: 0.0007798671722412109 seconds
# Time taken to evaluate population with C++ evaluator: 0.3744189739227295 seconds
# Time taken to calculate costs for g=35: 0.37793707847595215 seconds
# Lowest cost in generation 35: -955.03
# Time taken to sort population for g=35: 1.4066696166992188e-05 seconds
# Generation 37 of 100
# Time taken to breed kids for g=36: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=36: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.37535905838012695 seconds
# Time taken to calculate costs for g=36: 0.37894392013549805 seconds
# Lowest cost in generation 36: -955.03
# Time taken to sort population for g=36: 1.4066696166992188e-05 seconds
# Generation 38 of 100
# Time taken to breed kids for g=37: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=37: 0.0007822513580322266 seconds
# Time taken to evaluate population with C++ evaluator: 0.375194787979126 seconds
# Time taken to calculate costs for g=37: 0.37876081466674805 seconds
# Lowest cost in generation 37: -955.03
# Time taken to sort population for g=37: 1.3828277587890625e-05 seconds
# Generation 39 of 100
# Time taken to breed kids for g=38: 8.392333984375e-05 seconds
# Time taken to fill random members for g=38: 0.0007557868957519531 seconds
# Time taken to evaluate population with C++ evaluator: 0.3738422393798828 seconds
# Time taken to calculate costs for g=38: 0.3775608539581299 seconds
# Lowest cost in generation 38: -955.03
# Time taken to sort population for g=38: 1.2874603271484375e-05 seconds
# Generation 40 of 100
# Time taken to breed kids for g=39: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=39: 0.0007867813110351562 seconds
# Time taken to evaluate population with C++ evaluator: 0.37415099143981934 seconds
# Time taken to calculate costs for g=39: 0.37772679328918457 seconds
# Lowest cost in generation 39: -955.03
# Time taken to sort population for g=39: 1.3113021850585938e-05 seconds
# Generation 41 of 100
# Time taken to breed kids for g=40: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=40: 0.0007789134979248047 seconds
# Time taken to evaluate population with C++ evaluator: 0.3833038806915283 seconds
# Time taken to calculate costs for g=40: 0.38689088821411133 seconds
# Lowest cost in generation 40: -955.03
# Time taken to sort population for g=40: 1.52587890625e-05 seconds
# Generation 42 of 100
# Time taken to breed kids for g=41: 9.894371032714844e-05 seconds
# Time taken to fill random members for g=41: 0.0009400844573974609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3966038227081299 seconds
# Time taken to calculate costs for g=41: 0.4010434150695801 seconds
# Lowest cost in generation 41: -955.03
# Time taken to sort population for g=41: 2.002716064453125e-05 seconds
# Generation 43 of 100
# Time taken to breed kids for g=42: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=42: 0.0009217262268066406 seconds
# Time taken to evaluate population with C++ evaluator: 0.3837432861328125 seconds
# Time taken to calculate costs for g=42: 0.3892171382904053 seconds
# Lowest cost in generation 42: -955.03
# Time taken to sort population for g=42: 2.193450927734375e-05 seconds
# Generation 44 of 100
# Time taken to breed kids for g=43: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=43: 0.0010428428649902344 seconds
# Time taken to evaluate population with C++ evaluator: 0.4044058322906494 seconds
# Time taken to calculate costs for g=43: 0.40873193740844727 seconds
# Lowest cost in generation 43: -955.03
# Time taken to sort population for g=43: 1.5020370483398438e-05 seconds
# Generation 45 of 100
# Time taken to breed kids for g=44: 0.00010013580322265625 seconds
# Time taken to fill random members for g=44: 0.0009138584136962891 seconds
# Time taken to evaluate population with C++ evaluator: 0.3954601287841797 seconds
# Time taken to calculate costs for g=44: 0.4000871181488037 seconds
# Lowest cost in generation 44: -955.03
# Time taken to sort population for g=44: 1.6927719116210938e-05 seconds
# Generation 46 of 100
# Time taken to breed kids for g=45: 0.0001049041748046875 seconds
# Time taken to fill random members for g=45: 0.0007638931274414062 seconds
# Time taken to evaluate population with C++ evaluator: 0.3956277370452881 seconds
# Time taken to calculate costs for g=45: 0.3998258113861084 seconds
# Lowest cost in generation 45: -955.03
# Time taken to sort population for g=45: 1.4066696166992188e-05 seconds
# Generation 47 of 100
# Time taken to breed kids for g=46: 8.082389831542969e-05 seconds
# Time taken to fill random members for g=46: 0.0009770393371582031 seconds
# Time taken to evaluate population with C++ evaluator: 0.39400482177734375 seconds
# Time taken to calculate costs for g=46: 0.3984510898590088 seconds
# Lowest cost in generation 46: -955.03
# Time taken to sort population for g=46: 1.52587890625e-05 seconds
# Generation 48 of 100
# Time taken to breed kids for g=47: 0.000125885009765625 seconds
# Time taken to fill random members for g=47: 0.0007729530334472656 seconds
# Time taken to evaluate population with C++ evaluator: 0.3986072540283203 seconds
# Time taken to calculate costs for g=47: 0.4029850959777832 seconds
# Lowest cost in generation 47: -955.03
# Time taken to sort population for g=47: 6.508827209472656e-05 seconds
# Generation 49 of 100
# Time taken to breed kids for g=48: 0.00010704994201660156 seconds
# Time taken to fill random members for g=48: 0.0010399818420410156 seconds
# Time taken to evaluate population with C++ evaluator: 0.391948938369751 seconds
# Time taken to calculate costs for g=48: 0.3961970806121826 seconds
# Lowest cost in generation 48: -965.17
# Time taken to sort population for g=48: 2.8133392333984375e-05 seconds
# Generation 50 of 100
# Time taken to breed kids for g=49: 0.00011491775512695312 seconds
# Time taken to fill random members for g=49: 0.0008602142333984375 seconds
# Time taken to evaluate population with C++ evaluator: 0.39924120903015137 seconds
# Time taken to calculate costs for g=49: 0.404163122177124 seconds
# Lowest cost in generation 49: -965.17
# Time taken to sort population for g=49: 1.6927719116210938e-05 seconds
# Generation 51 of 100
# Time taken to breed kids for g=50: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=50: 0.0007598400115966797 seconds
# Time taken to evaluate population with C++ evaluator: 0.3876512050628662 seconds
# Time taken to calculate costs for g=50: 0.3917577266693115 seconds
# Lowest cost in generation 50: -970.66
# Time taken to sort population for g=50: 1.4066696166992188e-05 seconds
# Generation 52 of 100
# Time taken to breed kids for g=51: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=51: 0.0007688999176025391 seconds
# Time taken to evaluate population with C++ evaluator: 0.38122010231018066 seconds
# Time taken to calculate costs for g=51: 0.3849928379058838 seconds
# Lowest cost in generation 51: -971.36
# Time taken to sort population for g=51: 1.5020370483398438e-05 seconds
# Generation 53 of 100
# Time taken to breed kids for g=52: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=52: 0.0007970333099365234 seconds
# Time taken to evaluate population with C++ evaluator: 0.37921619415283203 seconds
# Time taken to calculate costs for g=52: 0.38280606269836426 seconds
# Lowest cost in generation 52: -971.36
# Time taken to sort population for g=52: 1.3828277587890625e-05 seconds
# Generation 54 of 100
# Time taken to breed kids for g=53: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=53: 0.0007557868957519531 seconds
# Time taken to evaluate population with C++ evaluator: 0.38140296936035156 seconds
# Time taken to calculate costs for g=53: 0.38513612747192383 seconds
# Lowest cost in generation 53: -973.02
# Time taken to sort population for g=53: 1.5974044799804688e-05 seconds
# Generation 55 of 100
# Time taken to breed kids for g=54: 0.00010085105895996094 seconds
# Time taken to fill random members for g=54: 0.00090789794921875 seconds
# Time taken to evaluate population with C++ evaluator: 0.3970530033111572 seconds
# Time taken to calculate costs for g=54: 0.4010779857635498 seconds
# Lowest cost in generation 54: -973.02
# Time taken to sort population for g=54: 1.4066696166992188e-05 seconds
# Generation 56 of 100
# Time taken to breed kids for g=55: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=55: 0.0007939338684082031 seconds
# Time taken to evaluate population with C++ evaluator: 0.3955719470977783 seconds
# Time taken to calculate costs for g=55: 0.39975810050964355 seconds
# Lowest cost in generation 55: -973.02
# Time taken to sort population for g=55: 1.430511474609375e-05 seconds
# Generation 57 of 100
# Time taken to breed kids for g=56: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=56: 0.0007488727569580078 seconds
# Time taken to evaluate population with C++ evaluator: 0.37810683250427246 seconds
# Time taken to calculate costs for g=56: 0.38172078132629395 seconds
# Lowest cost in generation 56: -973.48
# Time taken to sort population for g=56: 1.5020370483398438e-05 seconds
# Generation 58 of 100
# Time taken to breed kids for g=57: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=57: 0.0008749961853027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.372222900390625 seconds
# Time taken to calculate costs for g=57: 0.37590479850769043 seconds
# Lowest cost in generation 57: -978.51
# Time taken to sort population for g=57: 1.4066696166992188e-05 seconds
# Generation 59 of 100
# Time taken to breed kids for g=58: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=58: 0.0007681846618652344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3717777729034424 seconds
# Time taken to calculate costs for g=58: 0.3754920959472656 seconds
# Lowest cost in generation 58: -978.51
# Time taken to sort population for g=58: 1.4066696166992188e-05 seconds
# Generation 60 of 100
# Time taken to breed kids for g=59: 8.0108642578125e-05 seconds
# Time taken to fill random members for g=59: 0.0007250308990478516 seconds
# Time taken to evaluate population with C++ evaluator: 0.3730161190032959 seconds
# Time taken to calculate costs for g=59: 0.37656497955322266 seconds
# Lowest cost in generation 59: -978.51
# Time taken to sort population for g=59: 1.4066696166992188e-05 seconds
# Generation 61 of 100
# Time taken to breed kids for g=60: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=60: 0.0007460117340087891 seconds
# Time taken to evaluate population with C++ evaluator: 0.37390589714050293 seconds
# Time taken to calculate costs for g=60: 0.37738704681396484 seconds
# Lowest cost in generation 60: -978.51
# Time taken to sort population for g=60: 1.4066696166992188e-05 seconds
# Generation 62 of 100
# Time taken to breed kids for g=61: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=61: 0.0007350444793701172 seconds
# Time taken to evaluate population with C++ evaluator: 0.3714003562927246 seconds
# Time taken to calculate costs for g=61: 0.37528085708618164 seconds
# Lowest cost in generation 61: -978.51
# Time taken to sort population for g=61: 1.4066696166992188e-05 seconds
# Generation 63 of 100
# Time taken to breed kids for g=62: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=62: 0.0007507801055908203 seconds
# Time taken to evaluate population with C++ evaluator: 0.3723721504211426 seconds
# Time taken to calculate costs for g=62: 0.3758518695831299 seconds
# Lowest cost in generation 62: -981.76
# Time taken to sort population for g=62: 1.5735626220703125e-05 seconds
# Generation 64 of 100
# Time taken to breed kids for g=63: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=63: 0.0007581710815429688 seconds
# Time taken to evaluate population with C++ evaluator: 0.37258481979370117 seconds
# Time taken to calculate costs for g=63: 0.3761410713195801 seconds
# Lowest cost in generation 63: -981.76
# Time taken to sort population for g=63: 2.5033950805664062e-05 seconds
# Generation 65 of 100
# Time taken to breed kids for g=64: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=64: 0.0007390975952148438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3723409175872803 seconds
# Time taken to calculate costs for g=64: 0.3759329319000244 seconds
# Lowest cost in generation 64: -993.15
# Time taken to sort population for g=64: 1.2874603271484375e-05 seconds
# Generation 66 of 100
# Time taken to breed kids for g=65: 8.392333984375e-05 seconds
# Time taken to fill random members for g=65: 0.0007688999176025391 seconds
# Time taken to evaluate population with C++ evaluator: 0.374467134475708 seconds
# Time taken to calculate costs for g=65: 0.37802600860595703 seconds
# Lowest cost in generation 65: -993.15
# Time taken to sort population for g=65: 4.601478576660156e-05 seconds
# Generation 67 of 100
# Time taken to breed kids for g=66: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=66: 0.0007941722869873047 seconds
# Time taken to evaluate population with C++ evaluator: 0.3758976459503174 seconds
# Time taken to calculate costs for g=66: 0.379317045211792 seconds
# Lowest cost in generation 66: -995.34
# Time taken to sort population for g=66: 1.3589859008789062e-05 seconds
# Generation 68 of 100
# Time taken to breed kids for g=67: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=67: 0.0008678436279296875 seconds
# Time taken to evaluate population with C++ evaluator: 0.37443017959594727 seconds
# Time taken to calculate costs for g=67: 0.3782172203063965 seconds
# Lowest cost in generation 67: -995.38
# Time taken to sort population for g=67: 1.52587890625e-05 seconds
# Generation 69 of 100
# Time taken to breed kids for g=68: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=68: 0.0007829666137695312 seconds
# Time taken to evaluate population with C++ evaluator: 0.37299489974975586 seconds
# Time taken to calculate costs for g=68: 0.3765387535095215 seconds
# Lowest cost in generation 68: -995.38
# Time taken to sort population for g=68: 1.3828277587890625e-05 seconds
# Generation 70 of 100
# Time taken to breed kids for g=69: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=69: 0.0007572174072265625 seconds
# Time taken to evaluate population with C++ evaluator: 0.3726801872253418 seconds
# Time taken to calculate costs for g=69: 0.37641119956970215 seconds
# Lowest cost in generation 69: -995.38
# Time taken to sort population for g=69: 1.1682510375976562e-05 seconds
# Generation 71 of 100
# Time taken to breed kids for g=70: 8.106231689453125e-05 seconds
# Time taken to fill random members for g=70: 0.0007328987121582031 seconds
# Time taken to evaluate population with C++ evaluator: 0.4028747081756592 seconds
# Time taken to calculate costs for g=70: 0.40668416023254395 seconds
# Lowest cost in generation 70: -995.55
# Time taken to sort population for g=70: 1.5020370483398438e-05 seconds
# Generation 72 of 100
# Time taken to breed kids for g=71: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=71: 0.0008101463317871094 seconds
# Time taken to evaluate population with C++ evaluator: 0.40196990966796875 seconds
# Time taken to calculate costs for g=71: 0.4063129425048828 seconds
# Lowest cost in generation 71: -995.89
# Time taken to sort population for g=71: 1.3828277587890625e-05 seconds
# Generation 73 of 100
# Time taken to breed kids for g=72: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=72: 0.0007779598236083984 seconds
# Time taken to evaluate population with C++ evaluator: 0.38767290115356445 seconds
# Time taken to calculate costs for g=72: 0.3913261890411377 seconds
# Lowest cost in generation 72: -1031.14
# Time taken to sort population for g=72: 1.5020370483398438e-05 seconds
# Generation 74 of 100
# Time taken to breed kids for g=73: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=73: 0.0007731914520263672 seconds
# Time taken to evaluate population with C++ evaluator: 0.4003720283508301 seconds
# Time taken to calculate costs for g=73: 0.4047391414642334 seconds
# Lowest cost in generation 73: -1031.14
# Time taken to sort population for g=73: 1.4066696166992188e-05 seconds
# Generation 75 of 100
# Time taken to breed kids for g=74: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=74: 0.0007889270782470703 seconds
# Time taken to evaluate population with C++ evaluator: 0.38453102111816406 seconds
# Time taken to calculate costs for g=74: 0.38815903663635254 seconds
# Lowest cost in generation 74: -1031.14
# Time taken to sort population for g=74: 1.71661376953125e-05 seconds
# Generation 76 of 100
# Time taken to breed kids for g=75: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=75: 0.0008068084716796875 seconds
# Time taken to evaluate population with C++ evaluator: 0.3780479431152344 seconds
# Time taken to calculate costs for g=75: 0.38164615631103516 seconds
# Lowest cost in generation 75: -1031.14
# Time taken to sort population for g=75: 1.3113021850585938e-05 seconds
# Generation 77 of 100
# Time taken to breed kids for g=76: 8.20159912109375e-05 seconds
# Time taken to fill random members for g=76: 0.0007419586181640625 seconds
# Time taken to evaluate population with C++ evaluator: 0.37726497650146484 seconds
# Time taken to calculate costs for g=76: 0.38089704513549805 seconds
# Lowest cost in generation 76: -1033.99
# Time taken to sort population for g=76: 1.2636184692382812e-05 seconds
# Generation 78 of 100
# Time taken to breed kids for g=77: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=77: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.3776829242706299 seconds
# Time taken to calculate costs for g=77: 0.38132786750793457 seconds
# Lowest cost in generation 77: -1034.18
# Time taken to sort population for g=77: 1.3828277587890625e-05 seconds
# Generation 79 of 100
# Time taken to breed kids for g=78: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=78: 0.0007653236389160156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3782069683074951 seconds
# Time taken to calculate costs for g=78: 0.38207530975341797 seconds
# Lowest cost in generation 78: -1034.18
# Time taken to sort population for g=78: 1.4066696166992188e-05 seconds
# Generation 80 of 100
# Time taken to breed kids for g=79: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=79: 0.0007488727569580078 seconds
# Time taken to evaluate population with C++ evaluator: 0.376039981842041 seconds
# Time taken to calculate costs for g=79: 0.37967514991760254 seconds
# Lowest cost in generation 79: -1034.18
# Time taken to sort population for g=79: 1.2874603271484375e-05 seconds
# Generation 81 of 100
# Time taken to breed kids for g=80: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=80: 0.0007870197296142578 seconds
# Time taken to evaluate population with C++ evaluator: 0.37889790534973145 seconds
# Time taken to calculate costs for g=80: 0.3824589252471924 seconds
# Lowest cost in generation 80: -1034.18
# Time taken to sort population for g=80: 1.2874603271484375e-05 seconds
# Generation 82 of 100
# Time taken to breed kids for g=81: 8.320808410644531e-05 seconds
# Time taken to fill random members for g=81: 0.0008080005645751953 seconds
# Time taken to evaluate population with C++ evaluator: 0.3778519630432129 seconds
# Time taken to calculate costs for g=81: 0.3813791275024414 seconds
# Lowest cost in generation 81: -1034.18
# Time taken to sort population for g=81: 1.4066696166992188e-05 seconds
# Generation 83 of 100
# Time taken to breed kids for g=82: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=82: 0.0007548332214355469 seconds
# Time taken to evaluate population with C++ evaluator: 0.37949275970458984 seconds
# Time taken to calculate costs for g=82: 0.3830080032348633 seconds
# Lowest cost in generation 82: -1034.18
# Time taken to sort population for g=82: 1.5020370483398438e-05 seconds
# Generation 84 of 100
# Time taken to breed kids for g=83: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=83: 0.0007722377777099609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3757450580596924 seconds
# Time taken to calculate costs for g=83: 0.3792908191680908 seconds
# Lowest cost in generation 83: -1034.18
# Time taken to sort population for g=83: 1.3828277587890625e-05 seconds
# Generation 85 of 100
# Time taken to breed kids for g=84: 8.392333984375e-05 seconds
# Time taken to fill random members for g=84: 0.0007572174072265625 seconds
# Time taken to evaluate population with C++ evaluator: 0.3773529529571533 seconds
# Time taken to calculate costs for g=84: 0.3808159828186035 seconds
# Lowest cost in generation 84: -1034.18
# Time taken to sort population for g=84: 1.3113021850585938e-05 seconds
# Generation 86 of 100
# Time taken to breed kids for g=85: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=85: 0.0007300376892089844 seconds
# Time taken to evaluate population with C++ evaluator: 0.37741994857788086 seconds
# Time taken to calculate costs for g=85: 0.380983829498291 seconds
# Lowest cost in generation 85: -1034.18
# Time taken to sort population for g=85: 1.4066696166992188e-05 seconds
# Generation 87 of 100
# Time taken to breed kids for g=86: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=86: 0.0007650852203369141 seconds
# Time taken to evaluate population with C++ evaluator: 0.3755819797515869 seconds
# Time taken to calculate costs for g=86: 0.3791220188140869 seconds
# Lowest cost in generation 86: -1034.18
# Time taken to sort population for g=86: 1.2874603271484375e-05 seconds
# Generation 88 of 100
# Time taken to breed kids for g=87: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=87: 0.0008120536804199219 seconds
# Time taken to evaluate population with C++ evaluator: 0.3756132125854492 seconds
# Time taken to calculate costs for g=87: 0.3792450428009033 seconds
# Lowest cost in generation 87: -1034.18
# Time taken to sort population for g=87: 1.4066696166992188e-05 seconds
# Generation 89 of 100
# Time taken to breed kids for g=88: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=88: 0.0007691383361816406 seconds
# Time taken to evaluate population with C++ evaluator: 0.3782839775085449 seconds
# Time taken to calculate costs for g=88: 0.3819241523742676 seconds
# Lowest cost in generation 88: -1034.18
# Time taken to sort population for g=88: 1.4066696166992188e-05 seconds
# Generation 90 of 100
# Time taken to breed kids for g=89: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=89: 0.0007669925689697266 seconds
# Time taken to evaluate population with C++ evaluator: 0.3784980773925781 seconds
# Time taken to calculate costs for g=89: 0.38216233253479004 seconds
# Lowest cost in generation 89: -1034.18
# Time taken to sort population for g=89: 1.2636184692382812e-05 seconds
# Generation 91 of 100
# Time taken to breed kids for g=90: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=90: 0.0007579326629638672 seconds
# Time taken to evaluate population with C++ evaluator: 0.3811321258544922 seconds
# Time taken to calculate costs for g=90: 0.3847470283508301 seconds
# Lowest cost in generation 90: -1034.18
# Time taken to sort population for g=90: 1.3113021850585938e-05 seconds
# Generation 92 of 100
# Time taken to breed kids for g=91: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=91: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.37910914421081543 seconds
# Time taken to calculate costs for g=91: 0.38269591331481934 seconds
# Lowest cost in generation 91: -1034.18
# Time taken to sort population for g=91: 1.3828277587890625e-05 seconds
# Generation 93 of 100
# Time taken to breed kids for g=92: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=92: 0.0007889270782470703 seconds
# Time taken to evaluate population with C++ evaluator: 0.3783078193664551 seconds
# Time taken to calculate costs for g=92: 0.38194704055786133 seconds
# Lowest cost in generation 92: -1034.18
# Time taken to sort population for g=92: 1.621246337890625e-05 seconds
# Generation 94 of 100
# Time taken to breed kids for g=93: 0.00010776519775390625 seconds
# Time taken to fill random members for g=93: 0.0008029937744140625 seconds
# Time taken to evaluate population with C++ evaluator: 0.3784210681915283 seconds
# Time taken to calculate costs for g=93: 0.38182806968688965 seconds
# Lowest cost in generation 93: -1034.18
# Time taken to sort population for g=93: 1.5020370483398438e-05 seconds
# Generation 95 of 100
# Time taken to breed kids for g=94: 9.512901306152344e-05 seconds
# Time taken to fill random members for g=94: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3771359920501709 seconds
# Time taken to calculate costs for g=94: 0.3806309700012207 seconds
# Lowest cost in generation 94: -1034.18
# Time taken to sort population for g=94: 2.5987625122070312e-05 seconds
# Generation 96 of 100
# Time taken to breed kids for g=95: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=95: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.37583208084106445 seconds
# Time taken to calculate costs for g=95: 0.37947893142700195 seconds
# Lowest cost in generation 95: -1034.18
# Time taken to sort population for g=95: 1.4066696166992188e-05 seconds
# Generation 97 of 100
# Time taken to breed kids for g=96: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=96: 0.0007891654968261719 seconds
# Time taken to evaluate population with C++ evaluator: 0.38045501708984375 seconds
# Time taken to calculate costs for g=96: 0.38397979736328125 seconds
# Lowest cost in generation 96: -1034.18
# Time taken to sort population for g=96: 1.3113021850585938e-05 seconds
# Generation 98 of 100
# Time taken to breed kids for g=97: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=97: 0.0007739067077636719 seconds
# Time taken to evaluate population with C++ evaluator: 0.3810601234436035 seconds
# Time taken to calculate costs for g=97: 0.3846602439880371 seconds
# Lowest cost in generation 97: -1034.18
# Time taken to sort population for g=97: 1.5020370483398438e-05 seconds
# Generation 99 of 100
# Time taken to breed kids for g=98: 9.322166442871094e-05 seconds
# Time taken to fill random members for g=98: 0.0007939338684082031 seconds
# Time taken to evaluate population with C++ evaluator: 0.3893430233001709 seconds
# Time taken to calculate costs for g=98: 0.39296507835388184 seconds
# Lowest cost in generation 98: -1034.18
# Time taken to sort population for g=98: 1.7881393432617188e-05 seconds
# Generation 100 of 100
# Time taken to breed kids for g=99: 9.989738464355469e-05 seconds
# Time taken to fill random members for g=99: 0.0008339881896972656 seconds
# Time taken to evaluate population with C++ evaluator: 0.39890098571777344 seconds
# Time taken to calculate costs for g=99: 0.4032261371612549 seconds
# Lowest cost in generation 99: -1034.18
# Time taken to sort population for g=99: 1.4066696166992188e-05 seconds

# %%
with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "rb") as f:
    result = pickle.load(f)

# %%
[unique_values, unique_costs] = result.final_population.get_unique_designs()

# %%
unique_values_df = pd.DataFrame({
    'Irrigation frequency (every X hours)': unique_values[:, 0],
    'Irrigation amount (in)':               unique_values[:, 1],
    'Fertilizer frequency (every X hours)': unique_values[:, 2],
    'Fertilizer amount (lb)':               unique_values[:, 3],
    'Cost ($)':                             unique_costs,
    'Revenue ($)':                          -unique_costs,
})
unique_values_df.to_csv(f'ga_parallel_results/unique_values_costs_results/ga_parallel_result_unique_values_and_costs_{input_key}.csv', index=False)

# %%
result.print_table_of_best_designs()

# %%
result.plot_optimization_results()

# %%
min(unique_costs)
# Out:
# np.float64(-903.7191456412716)

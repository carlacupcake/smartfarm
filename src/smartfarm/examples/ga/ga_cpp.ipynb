# %%
# Import necessary modules
import numpy as np
import os
import pandas as pd
import pickle
import sys

here = os.path.dirname(os.path.abspath("__file__"))
project_root = os.path.abspath(os.path.join(here, '../../'))
sys.path.insert(0, project_root)

from core.ga.ga_bounds import DesignSpaceBounds
from core.ga.ga_params import GeneticAlgorithmParams
from core.ga.ga import GeneticAlgorithm

from core.model.model_carrying_capacities import ModelCarryingCapacities
from core.model.model_disturbances import ModelDisturbances
from core.model.model_growth_rates import ModelGrowthRates
from core.model.model_initial_conditions import ModelInitialConditions
from core.model.model_params import ModelParams
from core.model.model_typical_disturbances import ModelTypicalDisturbances
from core.model.model_sensitivities import ModelSensitivities

from ga_member_cpp import Evaluator

# %%
input_key = 10

# %% [markdown]
# ## Model Parameters

# %%
# Set ModelParams (time stepping)
model_params = ModelParams(
    dt               = 1.0,  # hours/step
    simulation_hours = 2900, # hours
    verbose          = True  # for the single simulation
)

# %%
# Set ModelCarryingCapacities
carrying_capacities = ModelCarryingCapacities(
    kh = 3.0,  # m
    kA = 0.65, # m2
    kN = 20,   # number of leaves
    kc = 1000, # number of spikelets
    kP = 0.25  # kg
)

# %%
# Set ModelGrowthRates
growth_rates = ModelGrowthRates(
    ah = 0.01,   # 1/hr
    aA = 0.0105, # 1/hr
    aN = 0.011,  # 1/hr
    ac = 0.01,   # 1/hr
    aP = 0.005   # 1/hr
)

# %%
# Set ModelSensitivities
sensitivities = ModelSensitivities(
    sigma_W = 30,  # hrs
    sigma_F = 300, # hrs
    sigma_T = 30,  # hrs
    sigma_R = 30   # hrs
)

# %%
# Set ModelInitialConditions
initial_conditions = ModelInitialConditions(
    h0=carrying_capacities.kh/model_params.simulation_hours, # m/hr
    A0=carrying_capacities.kA/model_params.simulation_hours, # m2/hr
    N0=carrying_capacities.kN/model_params.simulation_hours, # number/hr
    c0=carrying_capacities.kc/model_params.simulation_hours, # number/hr
    P0=carrying_capacities.kP/model_params.simulation_hours  # kg/hr
)

# %% [markdown]
# ## Design Space

# %%
lower_bounds_dict = {
    "irrigation_frequency":    12, # once every X hours
    "irrigation_amount":       0,  # inches per irrigation
    "fertilization_frequency": 24, # once every X hours (once a day)
    "fertilization_amount":    0   # pounds per fertilization
}
lower_bounds = np.array([value for key, value in lower_bounds_dict.items()])

# %%
upper_bounds_dict = {
    "irrigation_frequency":    2900,  # once a season
    "irrigation_amount":       10,    # inches per irrigation
    "fertilization_frequency": 2900,  # once a season
    "fertilization_amount":    700    # pounds per fertilization
}
upper_bounds = np.array([value for key, value in upper_bounds_dict.items()])

# %%
# Set DesignSpaceBounds
bounds = DesignSpaceBounds(
    lower_bounds=lower_bounds,
    upper_bounds=upper_bounds
)

# %% [markdown]
# ## Genetic Algorithm Parameters

# %%
# Genetic algorithm style inputs
ga_params = GeneticAlgorithmParams(
    num_parents     = 16,  # number of design strings to breed
    num_kids        = 16,  # number of offspring design strings
    num_generations = 100, # number of generations
    num_members     = 128, # number of simulations per generation
)

# %% [markdown]
# ## Input Disturbances

# %%
# Hourly precipitation, radiation, and temperature from CSV
hourly_input_disturbances = pd.read_csv(
    '../../io/inputs/hourly_prcp_rad_temp_iowa.csv'
)

# %%
# Set ModelDisturbances
input_disturbances = ModelDisturbances(
    precipitation = hourly_input_disturbances['Hourly Precipitation (in)'].to_numpy(),
    radiation     = hourly_input_disturbances['Hourly Radiation (W/m2)'].to_numpy(),
    temperature   = hourly_input_disturbances['Temperature (C)'].to_numpy()
)

# %% [markdown]
# ## Optimal/Typical Values

# %%
default_typical_disturbances = ModelTypicalDisturbances()

typical_disturbances = ModelTypicalDisturbances(
    typical_water       = default_typical_disturbances.typical_water * model_params.dt,
    typical_fertilizer  = default_typical_disturbances.typical_fertilizer * model_params.dt,
    typical_temperature = default_typical_disturbances.typical_temperature * model_params.dt,
    typical_radiation   = default_typical_disturbances.typical_radiation * model_params.dt
)

# %% [markdown]
# ## Single simulation

# %%
# Carla test params
irrigation_frequency = 24 * 7 * 2  # Irrigate once every 336 hours
irrigation_amount    = 0.23        # with 0.23 inches per irrigation (goal is 28 in including precip)
fertilizer_frequency = 24 * 30 * 3 # Fertilize once every 2160 hours
fertilizer_amount    = 175         # with 175 lbs per fertilization (goal is 355 lbs over season)

'''
# Example bad params
irrigation_frequency = 1
irrigation_amount    = 0
fertilizer_frequency = 1
fertilizer_amount    = 0
'''
# Out:
# '\n# Example bad params\nirrigation_frequency = 1\nirrigation_amount    = 0\nfertilizer_frequency = 1\nfertilizer_amount    = 0\n'

# %%
# Construct a single-member population Evaluator
from core.ga.ga_population import Population
population = Population(
    bounds               = bounds,
    ga_params            = ga_params,
    carrying_capacities  = carrying_capacities,
    disturbances         = input_disturbances,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    model_params         = model_params,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities,
    values = np.array([[irrigation_frequency, irrigation_amount, fertilizer_frequency, fertilizer_amount]])
)

# %%
population.set_costs_with_cpp()
cost_cpp = population.costs[0]
print(f"Cost from C++ Evaluator: {cost_cpp}")
# Out:
# Time taken to evaluate population with C++ evaluator: 0.0032227039337158203 seconds
# Cost from C++ Evaluator: -603.6537164537001

# %%
population.set_costs()
cost_py = population.costs[0]
print(f"Cost from Python Evaluator: {cost_py}")
# Out:
# Cost from Python Evaluator: -607.4450492586295

# %%
import time, numpy as np

# 1) context build
t0 = time.perf_counter()
ctx = population._build_sim_context_dict_cpp()
t1 = time.perf_counter()

# 2) evaluator construction
from ga_member_cpp import Evaluator
ev = Evaluator(ctx)
t2 = time.perf_counter()

# 3) evaluation (all 128)
X = np.ascontiguousarray(population.values, dtype=np.float64)  # IMPORTANT
costs = ev.evaluate_population(X)
t3 = time.perf_counter()

print("build ctx:", t1-t0)
print("make eval:", t2-t1)
print("eval pop :", t3-t2)
# Out:
# build ctx: 0.0025096661411225796
# make eval: 0.0018555419519543648
# eval pop : 0.003067875048145652

# %% [markdown]
# ## Genetic Algorithm

# %%
# Set verbose to False for GA runs
model_params.verbose = False

# Create GeneticAlgorithm object from all inputs
GeneticAlgorithm = GeneticAlgorithm(
    bounds               = bounds,
    ga_params            = ga_params,
    model_params         = model_params,
    carrying_capacities  = carrying_capacities,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    disturbances         = input_disturbances,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities
)

# %%
# Run the Genetic Algorithm and save the result

GeneticAlgorithmResult = GeneticAlgorithm.run_with_cpp()

with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "wb") as f:
    pickle.dump(GeneticAlgorithmResult, f)
# Out:
# Time taken to evaluate population with C++ evaluator: 0.3949291706085205 seconds
# Time taken to calculate costs for g=0: 0.3988831043243408 seconds
# Generation 2 of 100
# Time taken to breed kids for g=1: 0.00013113021850585938 seconds
# Time taken to fill random members for g=1: 0.0005221366882324219 seconds
# Time taken to evaluate population with C++ evaluator: 0.3933870792388916 seconds
# Time taken to calculate costs for g=1: 0.3969440460205078 seconds
# Lowest cost in generation 1: -924.75
# Time taken to sort population for g=1: 1.4781951904296875e-05 seconds
# Generation 3 of 100
# Time taken to breed kids for g=2: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=2: 0.0007278919219970703 seconds
# Time taken to evaluate population with C++ evaluator: 0.391556978225708 seconds
# Time taken to calculate costs for g=2: 0.3952929973602295 seconds
# Lowest cost in generation 2: -924.75
# Time taken to sort population for g=2: 1.430511474609375e-05 seconds
# Generation 4 of 100
# Time taken to breed kids for g=3: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=3: 0.0007548332214355469 seconds
# Time taken to evaluate population with C++ evaluator: 0.3954610824584961 seconds
# Time taken to calculate costs for g=3: 0.399186372756958 seconds
# Lowest cost in generation 3: -952.85
# Time taken to sort population for g=3: 1.3828277587890625e-05 seconds
# Generation 5 of 100
# Time taken to breed kids for g=4: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=4: 0.0007658004760742188 seconds
# Time taken to evaluate population with C++ evaluator: 0.3923909664154053 seconds
# Time taken to calculate costs for g=4: 0.3964710235595703 seconds
# Lowest cost in generation 4: -953.16
# Time taken to sort population for g=4: 1.3113021850585938e-05 seconds
# Generation 6 of 100
# Time taken to breed kids for g=5: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=5: 0.0007710456848144531 seconds
# Time taken to evaluate population with C++ evaluator: 0.3936159610748291 seconds
# Time taken to calculate costs for g=5: 0.3975250720977783 seconds
# Lowest cost in generation 5: -962.89
# Time taken to sort population for g=5: 1.3113021850585938e-05 seconds
# Generation 7 of 100
# Time taken to breed kids for g=6: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=6: 0.0031201839447021484 seconds
# Time taken to evaluate population with C++ evaluator: 0.39429807662963867 seconds
# Time taken to calculate costs for g=6: 0.39934802055358887 seconds
# Lowest cost in generation 6: -962.89
# Time taken to sort population for g=6: 1.4066696166992188e-05 seconds
# Generation 8 of 100
# Time taken to breed kids for g=7: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=7: 0.0008497238159179688 seconds
# Time taken to evaluate population with C++ evaluator: 0.39241504669189453 seconds
# Time taken to calculate costs for g=7: 0.39636969566345215 seconds
# Lowest cost in generation 7: -962.89
# Time taken to sort population for g=7: 1.4066696166992188e-05 seconds
# Generation 9 of 100
# Time taken to breed kids for g=8: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=8: 0.0007579326629638672 seconds
# Time taken to evaluate population with C++ evaluator: 0.3945279121398926 seconds
# Time taken to calculate costs for g=8: 0.39821314811706543 seconds
# Lowest cost in generation 8: -968.97
# Time taken to sort population for g=8: 1.5020370483398438e-05 seconds
# Generation 10 of 100
# Time taken to breed kids for g=9: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=9: 0.0007231235504150391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3938279151916504 seconds
# Time taken to calculate costs for g=9: 0.3976430892944336 seconds
# Lowest cost in generation 9: -968.97
# Time taken to sort population for g=9: 1.3113021850585938e-05 seconds
# Generation 11 of 100
# Time taken to breed kids for g=10: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=10: 0.0007491111755371094 seconds
# Time taken to evaluate population with C++ evaluator: 0.39215683937072754 seconds
# Time taken to calculate costs for g=10: 0.39587974548339844 seconds
# Lowest cost in generation 10: -971.17
# Time taken to sort population for g=10: 1.5020370483398438e-05 seconds
# Generation 12 of 100
# Time taken to breed kids for g=11: 0.00010013580322265625 seconds
# Time taken to fill random members for g=11: 0.0008261203765869141 seconds
# Time taken to evaluate population with C++ evaluator: 0.39499902725219727 seconds
# Time taken to calculate costs for g=11: 0.39873504638671875 seconds
# Lowest cost in generation 11: -971.17
# Time taken to sort population for g=11: 1.5974044799804688e-05 seconds
# Generation 13 of 100
# Time taken to breed kids for g=12: 9.608268737792969e-05 seconds
# Time taken to fill random members for g=12: 0.0007658004760742188 seconds
# Time taken to evaluate population with C++ evaluator: 0.39340901374816895 seconds
# Time taken to calculate costs for g=12: 0.39713191986083984 seconds
# Lowest cost in generation 12: -971.17
# Time taken to sort population for g=12: 1.3828277587890625e-05 seconds
# Generation 14 of 100
# Time taken to breed kids for g=13: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=13: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3986032009124756 seconds
# Time taken to calculate costs for g=13: 0.4023299217224121 seconds
# Lowest cost in generation 13: -973.22
# Time taken to sort population for g=13: 1.2874603271484375e-05 seconds
# Generation 15 of 100
# Time taken to breed kids for g=14: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=14: 0.0007379055023193359 seconds
# Time taken to evaluate population with C++ evaluator: 0.3962068557739258 seconds
# Time taken to calculate costs for g=14: 0.39988088607788086 seconds
# Lowest cost in generation 14: -973.22
# Time taken to sort population for g=14: 1.5020370483398438e-05 seconds
# Generation 16 of 100
# Time taken to breed kids for g=15: 0.00010180473327636719 seconds
# Time taken to fill random members for g=15: 0.0007989406585693359 seconds
# Time taken to evaluate population with C++ evaluator: 0.39188289642333984 seconds
# Time taken to calculate costs for g=15: 0.3955719470977783 seconds
# Lowest cost in generation 15: -973.22
# Time taken to sort population for g=15: 2.5033950805664062e-05 seconds
# Generation 17 of 100
# Time taken to breed kids for g=16: 9.870529174804688e-05 seconds
# Time taken to fill random members for g=16: 0.0007901191711425781 seconds
# Time taken to evaluate population with C++ evaluator: 0.39144420623779297 seconds
# Time taken to calculate costs for g=16: 0.3949871063232422 seconds
# Lowest cost in generation 16: -973.22
# Time taken to sort population for g=16: 1.71661376953125e-05 seconds
# Generation 18 of 100
# Time taken to breed kids for g=17: 9.918212890625e-05 seconds
# Time taken to fill random members for g=17: 0.0009088516235351562 seconds
# Time taken to evaluate population with C++ evaluator: 0.3917267322540283 seconds
# Time taken to calculate costs for g=17: 0.39536285400390625 seconds
# Lowest cost in generation 17: -973.22
# Time taken to sort population for g=17: 1.3828277587890625e-05 seconds
# Generation 19 of 100
# Time taken to breed kids for g=18: 0.00013208389282226562 seconds
# Time taken to fill random members for g=18: 0.0007600784301757812 seconds
# Time taken to evaluate population with C++ evaluator: 0.39350390434265137 seconds
# Time taken to calculate costs for g=18: 0.3972189426422119 seconds
# Lowest cost in generation 18: -973.22
# Time taken to sort population for g=18: 1.71661376953125e-05 seconds
# Generation 20 of 100
# Time taken to breed kids for g=19: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=19: 0.0007617473602294922 seconds
# Time taken to evaluate population with C++ evaluator: 0.39196109771728516 seconds
# Time taken to calculate costs for g=19: 0.3956420421600342 seconds
# Lowest cost in generation 19: -973.22
# Time taken to sort population for g=19: 1.4781951904296875e-05 seconds
# Generation 21 of 100
# Time taken to breed kids for g=20: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=20: 0.0008251667022705078 seconds
# Time taken to evaluate population with C++ evaluator: 0.3918590545654297 seconds
# Time taken to calculate costs for g=20: 0.3955690860748291 seconds
# Lowest cost in generation 20: -973.22
# Time taken to sort population for g=20: 1.7881393432617188e-05 seconds
# Generation 22 of 100
# Time taken to breed kids for g=21: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=21: 0.0008151531219482422 seconds
# Time taken to evaluate population with C++ evaluator: 0.3950018882751465 seconds
# Time taken to calculate costs for g=21: 0.3987610340118408 seconds
# Lowest cost in generation 21: -973.22
# Time taken to sort population for g=21: 1.3828277587890625e-05 seconds
# Generation 23 of 100
# Time taken to breed kids for g=22: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=22: 0.0007488727569580078 seconds
# Time taken to evaluate population with C++ evaluator: 0.39145779609680176 seconds
# Time taken to calculate costs for g=22: 0.39495301246643066 seconds
# Lowest cost in generation 22: -973.22
# Time taken to sort population for g=22: 1.8835067749023438e-05 seconds
# Generation 24 of 100
# Time taken to breed kids for g=23: 8.58306884765625e-05 seconds
# Time taken to fill random members for g=23: 0.0007240772247314453 seconds
# Time taken to evaluate population with C++ evaluator: 0.3937950134277344 seconds
# Time taken to calculate costs for g=23: 0.3975081443786621 seconds
# Lowest cost in generation 23: -973.22
# Time taken to sort population for g=23: 1.4066696166992188e-05 seconds
# Generation 25 of 100
# Time taken to breed kids for g=24: 9.989738464355469e-05 seconds
# Time taken to fill random members for g=24: 0.0009071826934814453 seconds
# Time taken to evaluate population with C++ evaluator: 0.3928380012512207 seconds
# Time taken to calculate costs for g=24: 0.39675188064575195 seconds
# Lowest cost in generation 24: -973.22
# Time taken to sort population for g=24: 1.4781951904296875e-05 seconds
# Generation 26 of 100
# Time taken to breed kids for g=25: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=25: 0.0007381439208984375 seconds
# Time taken to evaluate population with C++ evaluator: 0.394428014755249 seconds
# Time taken to calculate costs for g=25: 0.39812207221984863 seconds
# Lowest cost in generation 25: -973.22
# Time taken to sort population for g=25: 1.5974044799804688e-05 seconds
# Generation 27 of 100
# Time taken to breed kids for g=26: 9.799003601074219e-05 seconds
# Time taken to fill random members for g=26: 0.0009059906005859375 seconds
# Time taken to evaluate population with C++ evaluator: 0.3959839344024658 seconds
# Time taken to calculate costs for g=26: 0.39995288848876953 seconds
# Lowest cost in generation 26: -973.22
# Time taken to sort population for g=26: 1.3828277587890625e-05 seconds
# Generation 28 of 100
# Time taken to breed kids for g=27: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=27: 0.0007548332214355469 seconds
# Time taken to evaluate population with C++ evaluator: 0.3950989246368408 seconds
# Time taken to calculate costs for g=27: 0.398867130279541 seconds
# Lowest cost in generation 27: -973.22
# Time taken to sort population for g=27: 1.4066696166992188e-05 seconds
# Generation 29 of 100
# Time taken to breed kids for g=28: 8.726119995117188e-05 seconds
# Time taken to fill random members for g=28: 0.0007731914520263672 seconds
# Time taken to evaluate population with C++ evaluator: 0.39534521102905273 seconds
# Time taken to calculate costs for g=28: 0.39902782440185547 seconds
# Lowest cost in generation 28: -973.22
# Time taken to sort population for g=28: 1.3828277587890625e-05 seconds
# Generation 30 of 100
# Time taken to breed kids for g=29: 0.00011682510375976562 seconds
# Time taken to fill random members for g=29: 0.0007302761077880859 seconds
# Time taken to evaluate population with C++ evaluator: 0.3949577808380127 seconds
# Time taken to calculate costs for g=29: 0.39864301681518555 seconds
# Lowest cost in generation 29: -973.22
# Time taken to sort population for g=29: 1.4066696166992188e-05 seconds
# Generation 31 of 100
# Time taken to breed kids for g=30: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=30: 0.0007970333099365234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3926217555999756 seconds
# Time taken to calculate costs for g=30: 0.3963479995727539 seconds
# Lowest cost in generation 30: -973.22
# Time taken to sort population for g=30: 1.4066696166992188e-05 seconds
# Generation 32 of 100
# Time taken to breed kids for g=31: 8.392333984375e-05 seconds
# Time taken to fill random members for g=31: 0.0007348060607910156 seconds
# Time taken to evaluate population with C++ evaluator: 0.39432621002197266 seconds
# Time taken to calculate costs for g=31: 0.3979802131652832 seconds
# Lowest cost in generation 31: -973.22
# Time taken to sort population for g=31: 1.2636184692382812e-05 seconds
# Generation 33 of 100
# Time taken to breed kids for g=32: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=32: 0.0007300376892089844 seconds
# Time taken to evaluate population with C++ evaluator: 0.395366907119751 seconds
# Time taken to calculate costs for g=32: 0.3989551067352295 seconds
# Lowest cost in generation 32: -973.22
# Time taken to sort population for g=32: 1.4066696166992188e-05 seconds
# Generation 34 of 100
# Time taken to breed kids for g=33: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=33: 0.0007851123809814453 seconds
# Time taken to evaluate population with C++ evaluator: 0.3956570625305176 seconds
# Time taken to calculate costs for g=33: 0.39930272102355957 seconds
# Lowest cost in generation 33: -973.22
# Time taken to sort population for g=33: 1.4066696166992188e-05 seconds
# Generation 35 of 100
# Time taken to breed kids for g=34: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=34: 0.0007238388061523438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3942990303039551 seconds
# Time taken to calculate costs for g=34: 0.39800119400024414 seconds
# Lowest cost in generation 34: -973.22
# Time taken to sort population for g=34: 1.4066696166992188e-05 seconds
# Generation 36 of 100
# Time taken to breed kids for g=35: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=35: 0.0007879734039306641 seconds
# Time taken to evaluate population with C++ evaluator: 0.39374804496765137 seconds
# Time taken to calculate costs for g=35: 0.39726805686950684 seconds
# Lowest cost in generation 35: -973.22
# Time taken to sort population for g=35: 1.4066696166992188e-05 seconds
# Generation 37 of 100
# Time taken to breed kids for g=36: 9.608268737792969e-05 seconds
# Time taken to fill random members for g=36: 0.0007441043853759766 seconds
# Time taken to evaluate population with C++ evaluator: 0.39665913581848145 seconds
# Time taken to calculate costs for g=36: 0.4002842903137207 seconds
# Lowest cost in generation 36: -973.22
# Time taken to sort population for g=36: 1.5020370483398438e-05 seconds
# Generation 38 of 100
# Time taken to breed kids for g=37: 9.608268737792969e-05 seconds
# Time taken to fill random members for g=37: 0.0008900165557861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.39637231826782227 seconds
# Time taken to calculate costs for g=37: 0.3999629020690918 seconds
# Lowest cost in generation 37: -973.22
# Time taken to sort population for g=37: 1.5020370483398438e-05 seconds
# Generation 39 of 100
# Time taken to breed kids for g=38: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=38: 0.0007569789886474609 seconds
# Time taken to evaluate population with C++ evaluator: 0.39473700523376465 seconds
# Time taken to calculate costs for g=38: 0.3983170986175537 seconds
# Lowest cost in generation 38: -973.22
# Time taken to sort population for g=38: 1.4066696166992188e-05 seconds
# Generation 40 of 100
# Time taken to breed kids for g=39: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=39: 0.0007340908050537109 seconds
# Time taken to evaluate population with C++ evaluator: 0.39649391174316406 seconds
# Time taken to calculate costs for g=39: 0.40013599395751953 seconds
# Lowest cost in generation 39: -973.22
# Time taken to sort population for g=39: 1.4066696166992188e-05 seconds
# Generation 41 of 100
# Time taken to breed kids for g=40: 9.894371032714844e-05 seconds
# Time taken to fill random members for g=40: 0.0007781982421875 seconds
# Time taken to evaluate population with C++ evaluator: 0.392092227935791 seconds
# Time taken to calculate costs for g=40: 0.3959522247314453 seconds
# Lowest cost in generation 40: -973.22
# Time taken to sort population for g=40: 1.6927719116210938e-05 seconds
# Generation 42 of 100
# Time taken to breed kids for g=41: 9.107589721679688e-05 seconds
# Time taken to fill random members for g=41: 0.0007600784301757812 seconds
# Time taken to evaluate population with C++ evaluator: 0.39458513259887695 seconds
# Time taken to calculate costs for g=41: 0.39823079109191895 seconds
# Lowest cost in generation 41: -973.22
# Time taken to sort population for g=41: 1.3113021850585938e-05 seconds
# Generation 43 of 100
# Time taken to breed kids for g=42: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=42: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.3929431438446045 seconds
# Time taken to calculate costs for g=42: 0.3967111110687256 seconds
# Lowest cost in generation 42: -973.22
# Time taken to sort population for g=42: 1.3828277587890625e-05 seconds
# Generation 44 of 100
# Time taken to breed kids for g=43: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=43: 0.0007343292236328125 seconds
# Time taken to evaluate population with C++ evaluator: 0.39298200607299805 seconds
# Time taken to calculate costs for g=43: 0.3966410160064697 seconds
# Lowest cost in generation 43: -973.22
# Time taken to sort population for g=43: 1.2874603271484375e-05 seconds
# Generation 45 of 100
# Time taken to breed kids for g=44: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=44: 0.0007202625274658203 seconds
# Time taken to evaluate population with C++ evaluator: 0.39247632026672363 seconds
# Time taken to calculate costs for g=44: 0.39612603187561035 seconds
# Lowest cost in generation 44: -973.22
# Time taken to sort population for g=44: 1.3113021850585938e-05 seconds
# Generation 46 of 100
# Time taken to breed kids for g=45: 8.678436279296875e-05 seconds
# Time taken to fill random members for g=45: 0.0007696151733398438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3909158706665039 seconds
# Time taken to calculate costs for g=45: 0.3944990634918213 seconds
# Lowest cost in generation 45: -973.22
# Time taken to sort population for g=45: 1.4066696166992188e-05 seconds
# Generation 47 of 100
# Time taken to breed kids for g=46: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=46: 0.000759124755859375 seconds
# Time taken to evaluate population with C++ evaluator: 0.39616894721984863 seconds
# Time taken to calculate costs for g=46: 0.399843692779541 seconds
# Lowest cost in generation 46: -973.22
# Time taken to sort population for g=46: 1.3113021850585938e-05 seconds
# Generation 48 of 100
# Time taken to breed kids for g=47: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=47: 0.0007960796356201172 seconds
# Time taken to evaluate population with C++ evaluator: 0.3907897472381592 seconds
# Time taken to calculate costs for g=47: 0.39437198638916016 seconds
# Lowest cost in generation 47: -973.22
# Time taken to sort population for g=47: 1.5974044799804688e-05 seconds
# Generation 49 of 100
# Time taken to breed kids for g=48: 9.989738464355469e-05 seconds
# Time taken to fill random members for g=48: 0.0008039474487304688 seconds
# Time taken to evaluate population with C++ evaluator: 0.3946077823638916 seconds
# Time taken to calculate costs for g=48: 0.39818811416625977 seconds
# Lowest cost in generation 48: -973.22
# Time taken to sort population for g=48: 1.4066696166992188e-05 seconds
# Generation 50 of 100
# Time taken to breed kids for g=49: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=49: 0.0007717609405517578 seconds
# Time taken to evaluate population with C++ evaluator: 0.3940408229827881 seconds
# Time taken to calculate costs for g=49: 0.39768195152282715 seconds
# Lowest cost in generation 49: -973.22
# Time taken to sort population for g=49: 1.3828277587890625e-05 seconds
# Generation 51 of 100
# Time taken to breed kids for g=50: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=50: 0.0007658004760742188 seconds
# Time taken to evaluate population with C++ evaluator: 0.39168214797973633 seconds
# Time taken to calculate costs for g=50: 0.3954181671142578 seconds
# Lowest cost in generation 50: -973.22
# Time taken to sort population for g=50: 1.4066696166992188e-05 seconds
# Generation 52 of 100
# Time taken to breed kids for g=51: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=51: 0.0007450580596923828 seconds
# Time taken to evaluate population with C++ evaluator: 0.39447903633117676 seconds
# Time taken to calculate costs for g=51: 0.3979530334472656 seconds
# Lowest cost in generation 51: -973.22
# Time taken to sort population for g=51: 1.3113021850585938e-05 seconds
# Generation 53 of 100
# Time taken to breed kids for g=52: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=52: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3942689895629883 seconds
# Time taken to calculate costs for g=52: 0.397921085357666 seconds
# Lowest cost in generation 52: -973.22
# Time taken to sort population for g=52: 1.2159347534179688e-05 seconds
# Generation 54 of 100
# Time taken to breed kids for g=53: 8.177757263183594e-05 seconds
# Time taken to fill random members for g=53: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.39333176612854004 seconds
# Time taken to calculate costs for g=53: 0.3969581127166748 seconds
# Lowest cost in generation 53: -973.22
# Time taken to sort population for g=53: 1.430511474609375e-05 seconds
# Generation 55 of 100
# Time taken to breed kids for g=54: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=54: 0.0007350444793701172 seconds
# Time taken to evaluate population with C++ evaluator: 0.393967866897583 seconds
# Time taken to calculate costs for g=54: 0.397597074508667 seconds
# Lowest cost in generation 54: -973.22
# Time taken to sort population for g=54: 1.4066696166992188e-05 seconds
# Generation 56 of 100
# Time taken to breed kids for g=55: 9.608268737792969e-05 seconds
# Time taken to fill random members for g=55: 0.0006999969482421875 seconds
# Time taken to evaluate population with C++ evaluator: 0.391434907913208 seconds
# Time taken to calculate costs for g=55: 0.39510607719421387 seconds
# Lowest cost in generation 55: -973.22
# Time taken to sort population for g=55: 1.3828277587890625e-05 seconds
# Generation 57 of 100
# Time taken to breed kids for g=56: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=56: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3947720527648926 seconds
# Time taken to calculate costs for g=56: 0.3984341621398926 seconds
# Lowest cost in generation 56: -973.22
# Time taken to sort population for g=56: 1.3113021850585938e-05 seconds
# Generation 58 of 100
# Time taken to breed kids for g=57: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=57: 0.0007278919219970703 seconds
# Time taken to evaluate population with C++ evaluator: 0.39418911933898926 seconds
# Time taken to calculate costs for g=57: 0.39798593521118164 seconds
# Lowest cost in generation 57: -973.22
# Time taken to sort population for g=57: 1.4066696166992188e-05 seconds
# Generation 59 of 100
# Time taken to breed kids for g=58: 9.989738464355469e-05 seconds
# Time taken to fill random members for g=58: 0.0007398128509521484 seconds
# Time taken to evaluate population with C++ evaluator: 0.3960089683532715 seconds
# Time taken to calculate costs for g=58: 0.39969825744628906 seconds
# Lowest cost in generation 58: -973.22
# Time taken to sort population for g=58: 1.3828277587890625e-05 seconds
# Generation 60 of 100
# Time taken to breed kids for g=59: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=59: 0.0007810592651367188 seconds
# Time taken to evaluate population with C++ evaluator: 0.39372801780700684 seconds
# Time taken to calculate costs for g=59: 0.3974802494049072 seconds
# Lowest cost in generation 59: -973.22
# Time taken to sort population for g=59: 1.5020370483398438e-05 seconds
# Generation 61 of 100
# Time taken to breed kids for g=60: 9.799003601074219e-05 seconds
# Time taken to fill random members for g=60: 0.0007522106170654297 seconds
# Time taken to evaluate population with C++ evaluator: 0.39322805404663086 seconds
# Time taken to calculate costs for g=60: 0.3969268798828125 seconds
# Lowest cost in generation 60: -973.22
# Time taken to sort population for g=60: 1.4066696166992188e-05 seconds
# Generation 62 of 100
# Time taken to breed kids for g=61: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=61: 0.0007722377777099609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3949587345123291 seconds
# Time taken to calculate costs for g=61: 0.39854001998901367 seconds
# Lowest cost in generation 61: -973.22
# Time taken to sort population for g=61: 1.4066696166992188e-05 seconds
# Generation 63 of 100
# Time taken to breed kids for g=62: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=62: 0.0007348060607910156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3935511112213135 seconds
# Time taken to calculate costs for g=62: 0.3970952033996582 seconds
# Lowest cost in generation 62: -973.22
# Time taken to sort population for g=62: 1.3828277587890625e-05 seconds
# Generation 64 of 100
# Time taken to breed kids for g=63: 9.226799011230469e-05 seconds
# Time taken to fill random members for g=63: 0.0007410049438476562 seconds
# Time taken to evaluate population with C++ evaluator: 0.39666008949279785 seconds
# Time taken to calculate costs for g=63: 0.400266170501709 seconds
# Lowest cost in generation 63: -973.22
# Time taken to sort population for g=63: 1.4066696166992188e-05 seconds
# Generation 65 of 100
# Time taken to breed kids for g=64: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=64: 0.0008080005645751953 seconds
# Time taken to evaluate population with C++ evaluator: 0.3952159881591797 seconds
# Time taken to calculate costs for g=64: 0.3989901542663574 seconds
# Lowest cost in generation 64: -973.22
# Time taken to sort population for g=64: 1.4066696166992188e-05 seconds
# Generation 66 of 100
# Time taken to breed kids for g=65: 9.274482727050781e-05 seconds
# Time taken to fill random members for g=65: 0.0007758140563964844 seconds
# Time taken to evaluate population with C++ evaluator: 0.3953249454498291 seconds
# Time taken to calculate costs for g=65: 0.398939847946167 seconds
# Lowest cost in generation 65: -973.22
# Time taken to sort population for g=65: 1.4066696166992188e-05 seconds
# Generation 67 of 100
# Time taken to breed kids for g=66: 9.179115295410156e-05 seconds
# Time taken to fill random members for g=66: 0.0007739067077636719 seconds
# Time taken to evaluate population with C++ evaluator: 0.3953239917755127 seconds
# Time taken to calculate costs for g=66: 0.3988919258117676 seconds
# Lowest cost in generation 66: -973.22
# Time taken to sort population for g=66: 1.4066696166992188e-05 seconds
# Generation 68 of 100
# Time taken to breed kids for g=67: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=67: 0.0007669925689697266 seconds
# Time taken to evaluate population with C++ evaluator: 0.3941190242767334 seconds
# Time taken to calculate costs for g=67: 0.3976430892944336 seconds
# Lowest cost in generation 67: -973.22
# Time taken to sort population for g=67: 1.2159347534179688e-05 seconds
# Generation 69 of 100
# Time taken to breed kids for g=68: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=68: 0.0007801055908203125 seconds
# Time taken to evaluate population with C++ evaluator: 0.3956301212310791 seconds
# Time taken to calculate costs for g=68: 0.39937376976013184 seconds
# Lowest cost in generation 68: -995.36
# Time taken to sort population for g=68: 1.52587890625e-05 seconds
# Generation 70 of 100
# Time taken to breed kids for g=69: 9.512901306152344e-05 seconds
# Time taken to fill random members for g=69: 0.0007910728454589844 seconds
# Time taken to evaluate population with C++ evaluator: 0.39594316482543945 seconds
# Time taken to calculate costs for g=69: 0.39956116676330566 seconds
# Lowest cost in generation 69: -995.36
# Time taken to sort population for g=69: 1.4781951904296875e-05 seconds
# Generation 71 of 100
# Time taken to breed kids for g=70: 0.00010085105895996094 seconds
# Time taken to fill random members for g=70: 0.0007741451263427734 seconds
# Time taken to evaluate population with C++ evaluator: 0.3924429416656494 seconds
# Time taken to calculate costs for g=70: 0.3960890769958496 seconds
# Lowest cost in generation 70: -995.36
# Time taken to sort population for g=70: 1.2874603271484375e-05 seconds
# Generation 72 of 100
# Time taken to breed kids for g=71: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=71: 0.0007741451263427734 seconds
# Time taken to evaluate population with C++ evaluator: 0.39151883125305176 seconds
# Time taken to calculate costs for g=71: 0.39535999298095703 seconds
# Lowest cost in generation 71: -995.36
# Time taken to sort population for g=71: 1.3113021850585938e-05 seconds
# Generation 73 of 100
# Time taken to breed kids for g=72: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=72: 0.0007381439208984375 seconds
# Time taken to evaluate population with C++ evaluator: 0.3920619487762451 seconds
# Time taken to calculate costs for g=72: 0.3956789970397949 seconds
# Lowest cost in generation 72: -995.36
# Time taken to sort population for g=72: 1.2159347534179688e-05 seconds
# Generation 74 of 100
# Time taken to breed kids for g=73: 8.130073547363281e-05 seconds
# Time taken to fill random members for g=73: 0.0007219314575195312 seconds
# Time taken to evaluate population with C++ evaluator: 0.39315295219421387 seconds
# Time taken to calculate costs for g=73: 0.39673399925231934 seconds
# Lowest cost in generation 73: -995.36
# Time taken to sort population for g=73: 1.5020370483398438e-05 seconds
# Generation 75 of 100
# Time taken to breed kids for g=74: 0.00010800361633300781 seconds
# Time taken to fill random members for g=74: 0.0008251667022705078 seconds
# Time taken to evaluate population with C++ evaluator: 0.39702606201171875 seconds
# Time taken to calculate costs for g=74: 0.40096402168273926 seconds
# Lowest cost in generation 74: -995.62
# Time taken to sort population for g=74: 1.5020370483398438e-05 seconds
# Generation 76 of 100
# Time taken to breed kids for g=75: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=75: 0.0008499622344970703 seconds
# Time taken to evaluate population with C++ evaluator: 0.39565396308898926 seconds
# Time taken to calculate costs for g=75: 0.399554967880249 seconds
# Lowest cost in generation 75: -995.62
# Time taken to sort population for g=75: 1.2874603271484375e-05 seconds
# Generation 77 of 100
# Time taken to breed kids for g=76: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=76: 0.0007712841033935547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3951430320739746 seconds
# Time taken to calculate costs for g=76: 0.398845911026001 seconds
# Lowest cost in generation 76: -995.62
# Time taken to sort population for g=76: 1.4066696166992188e-05 seconds
# Generation 78 of 100
# Time taken to breed kids for g=77: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=77: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.39113402366638184 seconds
# Time taken to calculate costs for g=77: 0.39479494094848633 seconds
# Lowest cost in generation 77: -999.23
# Time taken to sort population for g=77: 1.3113021850585938e-05 seconds
# Generation 79 of 100
# Time taken to breed kids for g=78: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=78: 0.0007162094116210938 seconds
# Time taken to evaluate population with C++ evaluator: 0.39202213287353516 seconds
# Time taken to calculate costs for g=78: 0.39563703536987305 seconds
# Lowest cost in generation 78: -999.50
# Time taken to sort population for g=78: 1.4781951904296875e-05 seconds
# Generation 80 of 100
# Time taken to breed kids for g=79: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=79: 0.0007789134979248047 seconds
# Time taken to evaluate population with C++ evaluator: 0.39613795280456543 seconds
# Time taken to calculate costs for g=79: 0.4000561237335205 seconds
# Lowest cost in generation 79: -1000.26
# Time taken to sort population for g=79: 1.1920928955078125e-05 seconds
# Generation 81 of 100
# Time taken to breed kids for g=80: 7.987022399902344e-05 seconds
# Time taken to fill random members for g=80: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3922548294067383 seconds
# Time taken to calculate costs for g=80: 0.3960001468658447 seconds
# Lowest cost in generation 80: -1000.80
# Time taken to sort population for g=80: 1.4066696166992188e-05 seconds
# Generation 82 of 100
# Time taken to breed kids for g=81: 7.915496826171875e-05 seconds
# Time taken to fill random members for g=81: 0.0007369518280029297 seconds
# Time taken to evaluate population with C++ evaluator: 0.39700818061828613 seconds
# Time taken to calculate costs for g=81: 0.40062499046325684 seconds
# Lowest cost in generation 81: -1000.80
# Time taken to sort population for g=81: 1.4066696166992188e-05 seconds
# Generation 83 of 100
# Time taken to breed kids for g=82: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=82: 0.0007219314575195312 seconds
# Time taken to evaluate population with C++ evaluator: 0.3957788944244385 seconds
# Time taken to calculate costs for g=82: 0.39951491355895996 seconds
# Lowest cost in generation 82: -1001.62
# Time taken to sort population for g=82: 1.4066696166992188e-05 seconds
# Generation 84 of 100
# Time taken to breed kids for g=83: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=83: 0.0007557868957519531 seconds
# Time taken to evaluate population with C++ evaluator: 0.39090609550476074 seconds
# Time taken to calculate costs for g=83: 0.39445996284484863 seconds
# Lowest cost in generation 83: -1001.62
# Time taken to sort population for g=83: 1.3113021850585938e-05 seconds
# Generation 85 of 100
# Time taken to breed kids for g=84: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=84: 0.0007750988006591797 seconds
# Time taken to evaluate population with C++ evaluator: 0.3956296443939209 seconds
# Time taken to calculate costs for g=84: 0.3994178771972656 seconds
# Lowest cost in generation 84: -1001.62
# Time taken to sort population for g=84: 1.4066696166992188e-05 seconds
# Generation 86 of 100
# Time taken to breed kids for g=85: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=85: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.39298105239868164 seconds
# Time taken to calculate costs for g=85: 0.3966507911682129 seconds
# Lowest cost in generation 85: -1001.62
# Time taken to sort population for g=85: 1.3828277587890625e-05 seconds
# Generation 87 of 100
# Time taken to breed kids for g=86: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=86: 0.0007688999176025391 seconds
# Time taken to evaluate population with C++ evaluator: 0.39595890045166016 seconds
# Time taken to calculate costs for g=86: 0.3997459411621094 seconds
# Lowest cost in generation 86: -1001.62
# Time taken to sort population for g=86: 1.4066696166992188e-05 seconds
# Generation 88 of 100
# Time taken to breed kids for g=87: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=87: 0.0008111000061035156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3949849605560303 seconds
# Time taken to calculate costs for g=87: 0.3985331058502197 seconds
# Lowest cost in generation 87: -1001.62
# Time taken to sort population for g=87: 1.3828277587890625e-05 seconds
# Generation 89 of 100
# Time taken to breed kids for g=88: 9.274482727050781e-05 seconds
# Time taken to fill random members for g=88: 0.0007932186126708984 seconds
# Time taken to evaluate population with C++ evaluator: 0.39401698112487793 seconds
# Time taken to calculate costs for g=88: 0.3976118564605713 seconds
# Lowest cost in generation 88: -1001.62
# Time taken to sort population for g=88: 1.2636184692382812e-05 seconds
# Generation 90 of 100
# Time taken to breed kids for g=89: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=89: 0.0007669925689697266 seconds
# Time taken to evaluate population with C++ evaluator: 0.39643096923828125 seconds
# Time taken to calculate costs for g=89: 0.40015697479248047 seconds
# Lowest cost in generation 89: -1001.62
# Time taken to sort population for g=89: 1.4066696166992188e-05 seconds
# Generation 91 of 100
# Time taken to breed kids for g=90: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=90: 0.0007779598236083984 seconds
# Time taken to evaluate population with C++ evaluator: 0.39314794540405273 seconds
# Time taken to calculate costs for g=90: 0.39681100845336914 seconds
# Lowest cost in generation 90: -1001.62
# Time taken to sort population for g=90: 1.4066696166992188e-05 seconds
# Generation 92 of 100
# Time taken to breed kids for g=91: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=91: 0.0007598400115966797 seconds
# Time taken to evaluate population with C++ evaluator: 0.3975400924682617 seconds
# Time taken to calculate costs for g=91: 0.4011409282684326 seconds
# Lowest cost in generation 91: -1001.62
# Time taken to sort population for g=91: 1.52587890625e-05 seconds
# Generation 93 of 100
# Time taken to breed kids for g=92: 9.584426879882812e-05 seconds
# Time taken to fill random members for g=92: 0.000766754150390625 seconds
# Time taken to evaluate population with C++ evaluator: 0.3936786651611328 seconds
# Time taken to calculate costs for g=92: 0.39725804328918457 seconds
# Lowest cost in generation 92: -1001.62
# Time taken to sort population for g=92: 1.4066696166992188e-05 seconds
# Generation 94 of 100
# Time taken to breed kids for g=93: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=93: 0.0007827281951904297 seconds
# Time taken to evaluate population with C++ evaluator: 0.3952310085296631 seconds
# Time taken to calculate costs for g=93: 0.39888811111450195 seconds
# Lowest cost in generation 93: -1001.62
# Time taken to sort population for g=93: 1.71661376953125e-05 seconds
# Generation 95 of 100
# Time taken to breed kids for g=94: 9.894371032714844e-05 seconds
# Time taken to fill random members for g=94: 0.0007722377777099609 seconds
# Time taken to evaluate population with C++ evaluator: 0.40025901794433594 seconds
# Time taken to calculate costs for g=94: 0.40424132347106934 seconds
# Lowest cost in generation 94: -1001.62
# Time taken to sort population for g=94: 1.3113021850585938e-05 seconds
# Generation 96 of 100
# Time taken to breed kids for g=95: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=95: 0.0008189678192138672 seconds
# Time taken to evaluate population with C++ evaluator: 0.3961977958679199 seconds
# Time taken to calculate costs for g=95: 0.3999640941619873 seconds
# Lowest cost in generation 95: -1001.62
# Time taken to sort population for g=95: 1.2874603271484375e-05 seconds
# Generation 97 of 100
# Time taken to breed kids for g=96: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=96: 0.0008089542388916016 seconds
# Time taken to evaluate population with C++ evaluator: 0.39543604850769043 seconds
# Time taken to calculate costs for g=96: 0.3992781639099121 seconds
# Lowest cost in generation 96: -1001.62
# Time taken to sort population for g=96: 1.4066696166992188e-05 seconds
# Generation 98 of 100
# Time taken to breed kids for g=97: 0.00010991096496582031 seconds
# Time taken to fill random members for g=97: 0.0007741451263427734 seconds
# Time taken to evaluate population with C++ evaluator: 0.3954639434814453 seconds
# Time taken to calculate costs for g=97: 0.3991098403930664 seconds
# Lowest cost in generation 97: -1001.62
# Time taken to sort population for g=97: 1.4066696166992188e-05 seconds
# Generation 99 of 100
# Time taken to breed kids for g=98: 0.00011873245239257812 seconds
# Time taken to fill random members for g=98: 0.0007588863372802734 seconds
# Time taken to evaluate population with C++ evaluator: 0.3949260711669922 seconds
# Time taken to calculate costs for g=98: 0.3986020088195801 seconds
# Lowest cost in generation 98: -1001.62
# Time taken to sort population for g=98: 1.4066696166992188e-05 seconds
# Generation 100 of 100
# Time taken to breed kids for g=99: 9.822845458984375e-05 seconds
# Time taken to fill random members for g=99: 0.0008001327514648438 seconds
# Time taken to evaluate population with C++ evaluator: 0.39541125297546387 seconds
# Time taken to calculate costs for g=99: 0.39949512481689453 seconds
# Lowest cost in generation 99: -1001.62
# Time taken to sort population for g=99: 1.3113021850585938e-05 seconds

# %%
with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "rb") as f:
    result = pickle.load(f)

# %%
[unique_values, unique_costs] = result.final_population.get_unique_designs()

# %%
unique_values_df = pd.DataFrame({
    'Irrigation frequency (every X hours)': unique_values[:, 0],
    'Irrigation amount (in)':               unique_values[:, 1],
    'Fertilizer frequency (every X hours)': unique_values[:, 2],
    'Fertilizer amount (lb)':               unique_values[:, 3],
    'Cost ($)':                             unique_costs,
    'Revenue ($)':                          -unique_costs,
})
unique_values_df.to_csv(f'ga_parallel_results/unique_values_costs_results/ga_parallel_result_unique_values_and_costs_{input_key}.csv', index=False)

# %%
#result.print_table_of_best_designs()

# %%
result.plot_optimization_results()

# %%
min(unique_costs)
# Out:
# np.float64(-1041.1341096797871)

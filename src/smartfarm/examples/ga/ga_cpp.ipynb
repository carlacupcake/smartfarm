# %%
# Import necessary modules
import numpy as np
import os
import pandas as pd
import pickle
import sys

here = os.path.dirname(os.path.abspath("__file__"))
project_root = os.path.abspath(os.path.join(here, '../../'))
sys.path.insert(0, project_root)

from core.ga.ga_bounds import DesignSpaceBounds
from core.ga.ga_params import GeneticAlgorithmParams
from core.ga.ga import GeneticAlgorithm

from core.model.model_carrying_capacities import ModelCarryingCapacities
from core.model.model_disturbances import ModelDisturbances
from core.model.model_growth_rates import ModelGrowthRates
from core.model.model_initial_conditions import ModelInitialConditions
from core.model.model_params import ModelParams
from core.model.model_typical_disturbances import ModelTypicalDisturbances
from core.model.model_sensitivities import ModelSensitivities

from ga_member_cpp import Evaluator

# %%
input_key = 10

# %% [markdown]
# ## Model Parameters

# %%
# Set ModelParams (time stepping)
model_params = ModelParams(
    dt               = 1.0,  # hours/step
    simulation_hours = 2900, # hours
    verbose          = True  # for the single simulation
)

# %%
# Set ModelCarryingCapacities
carrying_capacities = ModelCarryingCapacities(
    kh = 3.0,  # m
    kA = 0.65, # m2
    kN = 20,   # number of leaves
    kc = 1000, # number of spikelets
    kP = 0.25  # kg
)

# %%
# Set ModelGrowthRates
growth_rates = ModelGrowthRates(
    ah = 0.01,   # 1/hr
    aA = 0.0105, # 1/hr
    aN = 0.011,  # 1/hr
    ac = 0.01,   # 1/hr
    aP = 0.005   # 1/hr
)

# %%
# Set ModelSensitivities
sensitivities = ModelSensitivities(
    sigma_W = 30,  # hrs
    sigma_F = 300, # hrs
    sigma_T = 30,  # hrs
    sigma_R = 30   # hrs
)

# %%
# Set ModelInitialConditions
initial_conditions = ModelInitialConditions(
    h0=carrying_capacities.kh/model_params.simulation_hours, # m/hr
    A0=carrying_capacities.kA/model_params.simulation_hours, # m2/hr
    N0=carrying_capacities.kN/model_params.simulation_hours, # number/hr
    c0=carrying_capacities.kc/model_params.simulation_hours, # number/hr
    P0=carrying_capacities.kP/model_params.simulation_hours  # kg/hr
)

# %% [markdown]
# ## Design Space

# %%
lower_bounds_dict = {
    "irrigation_frequency":    12, # once every X hours
    "irrigation_amount":       0,  # inches per irrigation
    "fertilization_frequency": 24, # once every X hours (once a day)
    "fertilization_amount":    0   # pounds per fertilization
}
lower_bounds = np.array([value for key, value in lower_bounds_dict.items()])

# %%
upper_bounds_dict = {
    "irrigation_frequency":    2900,  # once a season
    "irrigation_amount":       10,    # inches per irrigation
    "fertilization_frequency": 2900,  # once a season
    "fertilization_amount":    700    # pounds per fertilization
}
upper_bounds = np.array([value for key, value in upper_bounds_dict.items()])

# %%
# Set DesignSpaceBounds
bounds = DesignSpaceBounds(
    lower_bounds=lower_bounds,
    upper_bounds=upper_bounds
)

# %% [markdown]
# ## Genetic Algorithm Parameters

# %%
# Genetic algorithm style inputs
ga_params = GeneticAlgorithmParams(
    num_parents     = 16,  # number of design strings to breed
    num_kids        = 16,  # number of offspring design strings
    num_generations = 100, # number of generations
    num_members     = 128, # number of simulations per generation
)

# %% [markdown]
# ## Input Disturbances

# %%
# Hourly precipitation, radiation, and temperature from CSV
hourly_input_disturbances = pd.read_csv(
    '../../io/inputs/hourly_prcp_rad_temp_iowa.csv'
)

# %%
# Set ModelDisturbances
input_disturbances = ModelDisturbances(
    precipitation = 0.5*hourly_input_disturbances['Hourly Precipitation (in)'].to_numpy(), # drought year
    radiation     = hourly_input_disturbances['Hourly Radiation (W/m2)'].to_numpy(),
    temperature   = hourly_input_disturbances['Temperature (C)'].to_numpy()
)

# %% [markdown]
# ## Optimal/Typical Values

# %%
default_typical_disturbances = ModelTypicalDisturbances()

typical_disturbances = ModelTypicalDisturbances(
    typical_water       = default_typical_disturbances.typical_water       * model_params.dt,
    typical_fertilizer  = default_typical_disturbances.typical_fertilizer  * model_params.dt,
    typical_temperature = default_typical_disturbances.typical_temperature * model_params.dt,
    typical_radiation   = default_typical_disturbances.typical_radiation   * model_params.dt
)

# %% [markdown]
# ## Single simulation

# %%
# Carla test params
irrigation_frequency = 24 * 7 * 2  # Irrigate once every 336 hours
irrigation_amount    = 0.23        # with 0.23 inches per irrigation (goal is 28 in including precip)
fertilizer_frequency = 24 * 30 * 3 # Fertilize once every 2160 hours
fertilizer_amount    = 175         # with 175 lbs per fertilization (goal is 355 lbs over season)

'''
# Example bad params
irrigation_frequency = 1
irrigation_amount    = 0
fertilizer_frequency = 1
fertilizer_amount    = 0
'''
# Out:
# '\n# Example bad params\nirrigation_frequency = 1\nirrigation_amount    = 0\nfertilizer_frequency = 1\nfertilizer_amount    = 0\n'

# %%
# Construct a single-member population Evaluator
from core.ga.ga_population import Population
population = Population(
    bounds               = bounds,
    ga_params            = ga_params,
    carrying_capacities  = carrying_capacities,
    disturbances         = input_disturbances,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    model_params         = model_params,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities,
    values = np.array([[irrigation_frequency, irrigation_amount, fertilizer_frequency, fertilizer_amount]])
)

# %%
population.set_costs_with_cpp()
cost_cpp = population.costs[0]
print(f"Cost from C++ Evaluator: {cost_cpp}")
# Out:
# Time taken to evaluate population with C++ evaluator: 0.003020048141479492 seconds
# Cost from C++ Evaluator: -465.605737525557

# %%
population.set_costs()
cost_py = population.costs[0]
print(f"Cost from Python Evaluator: {cost_py}")
# Out:
# Cost from Python Evaluator: -468.61545509199976

# %%
import time, numpy as np

# 1) context build
t0 = time.perf_counter()
ctx = population._build_sim_context_dict_cpp()
t1 = time.perf_counter()

# 2) evaluator construction
from ga_member_cpp import Evaluator
ev = Evaluator(ctx)
t2 = time.perf_counter()

# 3) evaluation (all 128)
X = np.ascontiguousarray(population.values, dtype=np.float64)  # IMPORTANT
costs = ev.evaluate_population(X)
t3 = time.perf_counter()

print("build ctx:", t1-t0)
print("make eval:", t2-t1)
print("eval pop :", t3-t2)
# Out:
# build ctx: 0.0028475411236286163
# make eval: 0.0018965420313179493
# eval pop : 0.0029873750172555447

# %% [markdown]
# ## Genetic Algorithm

# %%
# Set verbose to False for GA runs
model_params.verbose = False

# Create GeneticAlgorithm object from all inputs
GeneticAlgorithm = GeneticAlgorithm(
    bounds               = bounds,
    ga_params            = ga_params,
    model_params         = model_params,
    carrying_capacities  = carrying_capacities,
    growth_rates         = growth_rates,
    initial_conditions   = initial_conditions,
    disturbances         = input_disturbances,
    typical_disturbances = typical_disturbances,
    sensitivities        = sensitivities
)

# %%
# Run the Genetic Algorithm and save the result

GeneticAlgorithmResult = GeneticAlgorithm.run_with_cpp()

with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "wb") as f:
    pickle.dump(GeneticAlgorithmResult, f)
# Out:
# Time taken to evaluate population with C++ evaluator: 0.38182806968688965 seconds
# Time taken to calculate costs for g=0: 0.3861660957336426 seconds
# Generation 2 of 100
# Time taken to breed kids for g=1: 0.0001251697540283203 seconds
# Time taken to fill random members for g=1: 0.000518798828125 seconds
# Time taken to evaluate population with C++ evaluator: 0.378756046295166 seconds
# Time taken to calculate costs for g=1: 0.3824129104614258 seconds
# Lowest cost in generation 1: -840.91
# Time taken to sort population for g=1: 2.47955322265625e-05 seconds
# Generation 3 of 100
# Time taken to breed kids for g=2: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=2: 0.0007469654083251953 seconds
# Time taken to evaluate population with C++ evaluator: 0.3798031806945801 seconds
# Time taken to calculate costs for g=2: 0.3836207389831543 seconds
# Lowest cost in generation 2: -840.91
# Time taken to sort population for g=2: 1.7881393432617188e-05 seconds
# Generation 4 of 100
# Time taken to breed kids for g=3: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=3: 0.0007498264312744141 seconds
# Time taken to evaluate population with C++ evaluator: 0.37919163703918457 seconds
# Time taken to calculate costs for g=3: 0.38309288024902344 seconds
# Lowest cost in generation 3: -918.79
# Time taken to sort population for g=3: 1.5974044799804688e-05 seconds
# Generation 5 of 100
# Time taken to breed kids for g=4: 0.00010895729064941406 seconds
# Time taken to fill random members for g=4: 0.0007994174957275391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3805387020111084 seconds
# Time taken to calculate costs for g=4: 0.3844618797302246 seconds
# Lowest cost in generation 4: -941.15
# Time taken to sort population for g=4: 1.4066696166992188e-05 seconds
# Generation 6 of 100
# Time taken to breed kids for g=5: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=5: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3824310302734375 seconds
# Time taken to calculate costs for g=5: 0.3864560127258301 seconds
# Lowest cost in generation 5: -946.06
# Time taken to sort population for g=5: 1.5020370483398438e-05 seconds
# Generation 7 of 100
# Time taken to breed kids for g=6: 0.00010013580322265625 seconds
# Time taken to fill random members for g=6: 0.0009169578552246094 seconds
# Time taken to evaluate population with C++ evaluator: 0.3936772346496582 seconds
# Time taken to calculate costs for g=6: 0.39741015434265137 seconds
# Lowest cost in generation 6: -946.06
# Time taken to sort population for g=6: 1.52587890625e-05 seconds
# Generation 8 of 100
# Time taken to breed kids for g=7: 9.584426879882812e-05 seconds
# Time taken to fill random members for g=7: 0.0007851123809814453 seconds
# Time taken to evaluate population with C++ evaluator: 0.383620023727417 seconds
# Time taken to calculate costs for g=7: 0.38763904571533203 seconds
# Lowest cost in generation 7: -946.63
# Time taken to sort population for g=7: 1.2874603271484375e-05 seconds
# Generation 9 of 100
# Time taken to breed kids for g=8: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=8: 0.000743865966796875 seconds
# Time taken to evaluate population with C++ evaluator: 0.38324499130249023 seconds
# Time taken to calculate costs for g=8: 0.38730502128601074 seconds
# Lowest cost in generation 8: -946.63
# Time taken to sort population for g=8: 1.4066696166992188e-05 seconds
# Generation 10 of 100
# Time taken to breed kids for g=9: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=9: 0.0007708072662353516 seconds
# Time taken to evaluate population with C++ evaluator: 0.38723301887512207 seconds
# Time taken to calculate costs for g=9: 0.3912191390991211 seconds
# Lowest cost in generation 9: -946.63
# Time taken to sort population for g=9: 1.621246337890625e-05 seconds
# Generation 11 of 100
# Time taken to breed kids for g=10: 0.0001270771026611328 seconds
# Time taken to fill random members for g=10: 0.0008618831634521484 seconds
# Time taken to evaluate population with C++ evaluator: 0.38178110122680664 seconds
# Time taken to calculate costs for g=10: 0.38573694229125977 seconds
# Lowest cost in generation 10: -946.63
# Time taken to sort population for g=10: 1.2636184692382812e-05 seconds
# Generation 12 of 100
# Time taken to breed kids for g=11: 7.915496826171875e-05 seconds
# Time taken to fill random members for g=11: 0.0007512569427490234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3847811222076416 seconds
# Time taken to calculate costs for g=11: 0.38861608505249023 seconds
# Lowest cost in generation 11: -946.63
# Time taken to sort population for g=11: 1.3828277587890625e-05 seconds
# Generation 13 of 100
# Time taken to breed kids for g=12: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=12: 0.0007371902465820312 seconds
# Time taken to evaluate population with C++ evaluator: 0.38288092613220215 seconds
# Time taken to calculate costs for g=12: 0.3868851661682129 seconds
# Lowest cost in generation 12: -946.63
# Time taken to sort population for g=12: 1.3828277587890625e-05 seconds
# Generation 14 of 100
# Time taken to breed kids for g=13: 8.320808410644531e-05 seconds
# Time taken to fill random members for g=13: 0.0007297992706298828 seconds
# Time taken to evaluate population with C++ evaluator: 0.3811490535736084 seconds
# Time taken to calculate costs for g=13: 0.38495492935180664 seconds
# Lowest cost in generation 13: -946.63
# Time taken to sort population for g=13: 1.3828277587890625e-05 seconds
# Generation 15 of 100
# Time taken to breed kids for g=14: 9.894371032714844e-05 seconds
# Time taken to fill random members for g=14: 0.0009291172027587891 seconds
# Time taken to evaluate population with C++ evaluator: 0.3856799602508545 seconds
# Time taken to calculate costs for g=14: 0.38941216468811035 seconds
# Lowest cost in generation 14: -946.63
# Time taken to sort population for g=14: 1.3113021850585938e-05 seconds
# Generation 16 of 100
# Time taken to breed kids for g=15: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=15: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.3809700012207031 seconds
# Time taken to calculate costs for g=15: 0.3848226070404053 seconds
# Lowest cost in generation 15: -946.63
# Time taken to sort population for g=15: 1.4066696166992188e-05 seconds
# Generation 17 of 100
# Time taken to breed kids for g=16: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=16: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3865058422088623 seconds
# Time taken to calculate costs for g=16: 0.3903799057006836 seconds
# Lowest cost in generation 16: -946.63
# Time taken to sort population for g=16: 1.8835067749023438e-05 seconds
# Generation 18 of 100
# Time taken to breed kids for g=17: 0.0001800060272216797 seconds
# Time taken to fill random members for g=17: 0.000720977783203125 seconds
# Time taken to evaluate population with C++ evaluator: 0.3839590549468994 seconds
# Time taken to calculate costs for g=17: 0.38780713081359863 seconds
# Lowest cost in generation 17: -946.63
# Time taken to sort population for g=17: 1.52587890625e-05 seconds
# Generation 19 of 100
# Time taken to breed kids for g=18: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=18: 0.0007429122924804688 seconds
# Time taken to evaluate population with C++ evaluator: 0.38231706619262695 seconds
# Time taken to calculate costs for g=18: 0.38611507415771484 seconds
# Lowest cost in generation 18: -946.63
# Time taken to sort population for g=18: 2.384185791015625e-05 seconds
# Generation 20 of 100
# Time taken to breed kids for g=19: 0.00010013580322265625 seconds
# Time taken to fill random members for g=19: 0.0009150505065917969 seconds
# Time taken to evaluate population with C++ evaluator: 0.3911569118499756 seconds
# Time taken to calculate costs for g=19: 0.39499807357788086 seconds
# Lowest cost in generation 19: -946.63
# Time taken to sort population for g=19: 1.621246337890625e-05 seconds
# Generation 21 of 100
# Time taken to breed kids for g=20: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=20: 0.0007741451263427734 seconds
# Time taken to evaluate population with C++ evaluator: 0.38381385803222656 seconds
# Time taken to calculate costs for g=20: 0.38767313957214355 seconds
# Lowest cost in generation 20: -946.63
# Time taken to sort population for g=20: 1.3113021850585938e-05 seconds
# Generation 22 of 100
# Time taken to breed kids for g=21: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=21: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3848247528076172 seconds
# Time taken to calculate costs for g=21: 0.3888208866119385 seconds
# Lowest cost in generation 21: -946.63
# Time taken to sort population for g=21: 1.4066696166992188e-05 seconds
# Generation 23 of 100
# Time taken to breed kids for g=22: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=22: 0.0007770061492919922 seconds
# Time taken to evaluate population with C++ evaluator: 0.38490891456604004 seconds
# Time taken to calculate costs for g=22: 0.38899779319763184 seconds
# Lowest cost in generation 22: -946.63
# Time taken to sort population for g=22: 1.4066696166992188e-05 seconds
# Generation 24 of 100
# Time taken to breed kids for g=23: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=23: 0.0007269382476806641 seconds
# Time taken to evaluate population with C++ evaluator: 0.3805229663848877 seconds
# Time taken to calculate costs for g=23: 0.384321928024292 seconds
# Lowest cost in generation 23: -946.63
# Time taken to sort population for g=23: 1.3828277587890625e-05 seconds
# Generation 25 of 100
# Time taken to breed kids for g=24: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=24: 0.0007898807525634766 seconds
# Time taken to evaluate population with C++ evaluator: 0.38260412216186523 seconds
# Time taken to calculate costs for g=24: 0.38649892807006836 seconds
# Lowest cost in generation 24: -946.63
# Time taken to sort population for g=24: 1.3113021850585938e-05 seconds
# Generation 26 of 100
# Time taken to breed kids for g=25: 8.0108642578125e-05 seconds
# Time taken to fill random members for g=25: 0.0007128715515136719 seconds
# Time taken to evaluate population with C++ evaluator: 0.38248777389526367 seconds
# Time taken to calculate costs for g=25: 0.3862588405609131 seconds
# Lowest cost in generation 25: -946.63
# Time taken to sort population for g=25: 1.4781951904296875e-05 seconds
# Generation 27 of 100
# Time taken to breed kids for g=26: 8.392333984375e-05 seconds
# Time taken to fill random members for g=26: 0.0007357597351074219 seconds
# Time taken to evaluate population with C++ evaluator: 0.38136911392211914 seconds
# Time taken to calculate costs for g=26: 0.38547301292419434 seconds
# Lowest cost in generation 26: -946.63
# Time taken to sort population for g=26: 1.3828277587890625e-05 seconds
# Generation 28 of 100
# Time taken to breed kids for g=27: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=27: 0.0007278919219970703 seconds
# Time taken to evaluate population with C++ evaluator: 0.38249707221984863 seconds
# Time taken to calculate costs for g=27: 0.38635683059692383 seconds
# Lowest cost in generation 27: -946.63
# Time taken to sort population for g=27: 1.4066696166992188e-05 seconds
# Generation 29 of 100
# Time taken to breed kids for g=28: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=28: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3799631595611572 seconds
# Time taken to calculate costs for g=28: 0.3837890625 seconds
# Lowest cost in generation 28: -946.63
# Time taken to sort population for g=28: 1.2874603271484375e-05 seconds
# Generation 30 of 100
# Time taken to breed kids for g=29: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=29: 0.0007700920104980469 seconds
# Time taken to evaluate population with C++ evaluator: 0.3817760944366455 seconds
# Time taken to calculate costs for g=29: 0.38565826416015625 seconds
# Lowest cost in generation 29: -946.63
# Time taken to sort population for g=29: 1.4066696166992188e-05 seconds
# Generation 31 of 100
# Time taken to breed kids for g=30: 8.392333984375e-05 seconds
# Time taken to fill random members for g=30: 0.0007681846618652344 seconds
# Time taken to evaluate population with C++ evaluator: 0.3862168788909912 seconds
# Time taken to calculate costs for g=30: 0.39005494117736816 seconds
# Lowest cost in generation 30: -946.63
# Time taken to sort population for g=30: 1.3828277587890625e-05 seconds
# Generation 32 of 100
# Time taken to breed kids for g=31: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=31: 0.0007250308990478516 seconds
# Time taken to evaluate population with C++ evaluator: 0.38540005683898926 seconds
# Time taken to calculate costs for g=31: 0.3892807960510254 seconds
# Lowest cost in generation 31: -946.63
# Time taken to sort population for g=31: 1.4066696166992188e-05 seconds
# Generation 33 of 100
# Time taken to breed kids for g=32: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=32: 0.0007860660552978516 seconds
# Time taken to evaluate population with C++ evaluator: 0.3863670825958252 seconds
# Time taken to calculate costs for g=32: 0.39046311378479004 seconds
# Lowest cost in generation 32: -946.63
# Time taken to sort population for g=32: 1.621246337890625e-05 seconds
# Generation 34 of 100
# Time taken to breed kids for g=33: 9.202957153320312e-05 seconds
# Time taken to fill random members for g=33: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3850820064544678 seconds
# Time taken to calculate costs for g=33: 0.3890268802642822 seconds
# Lowest cost in generation 33: -946.63
# Time taken to sort population for g=33: 1.3828277587890625e-05 seconds
# Generation 35 of 100
# Time taken to breed kids for g=34: 9.298324584960938e-05 seconds
# Time taken to fill random members for g=34: 0.0007498264312744141 seconds
# Time taken to evaluate population with C++ evaluator: 0.3837771415710449 seconds
# Time taken to calculate costs for g=34: 0.3875880241394043 seconds
# Lowest cost in generation 34: -946.63
# Time taken to sort population for g=34: 1.8835067749023438e-05 seconds
# Generation 36 of 100
# Time taken to breed kids for g=35: 8.869171142578125e-05 seconds
# Time taken to fill random members for g=35: 0.0009400844573974609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3852999210357666 seconds
# Time taken to calculate costs for g=35: 0.38919806480407715 seconds
# Lowest cost in generation 35: -946.63
# Time taken to sort population for g=35: 1.621246337890625e-05 seconds
# Generation 37 of 100
# Time taken to breed kids for g=36: 7.510185241699219e-05 seconds
# Time taken to fill random members for g=36: 0.0006299018859863281 seconds
# Time taken to evaluate population with C++ evaluator: 0.3831188678741455 seconds
# Time taken to calculate costs for g=36: 0.3869478702545166 seconds
# Lowest cost in generation 36: -946.63
# Time taken to sort population for g=36: 1.4066696166992188e-05 seconds
# Generation 38 of 100
# Time taken to breed kids for g=37: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=37: 0.0008020401000976562 seconds
# Time taken to evaluate population with C++ evaluator: 0.3859291076660156 seconds
# Time taken to calculate costs for g=37: 0.38973402976989746 seconds
# Lowest cost in generation 37: -946.63
# Time taken to sort population for g=37: 1.4066696166992188e-05 seconds
# Generation 39 of 100
# Time taken to breed kids for g=38: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=38: 0.0007939338684082031 seconds
# Time taken to evaluate population with C++ evaluator: 0.3847188949584961 seconds
# Time taken to calculate costs for g=38: 0.3885462284088135 seconds
# Lowest cost in generation 38: -946.63
# Time taken to sort population for g=38: 1.5974044799804688e-05 seconds
# Generation 40 of 100
# Time taken to breed kids for g=39: 9.417533874511719e-05 seconds
# Time taken to fill random members for g=39: 0.0007810592651367188 seconds
# Time taken to evaluate population with C++ evaluator: 0.383897066116333 seconds
# Time taken to calculate costs for g=39: 0.38766002655029297 seconds
# Lowest cost in generation 39: -946.63
# Time taken to sort population for g=39: 1.2636184692382812e-05 seconds
# Generation 41 of 100
# Time taken to breed kids for g=40: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=40: 0.0007905960083007812 seconds
# Time taken to evaluate population with C++ evaluator: 0.38567090034484863 seconds
# Time taken to calculate costs for g=40: 0.38967204093933105 seconds
# Lowest cost in generation 40: -946.63
# Time taken to sort population for g=40: 1.2874603271484375e-05 seconds
# Generation 42 of 100
# Time taken to breed kids for g=41: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=41: 0.0007872581481933594 seconds
# Time taken to evaluate population with C++ evaluator: 0.3856029510498047 seconds
# Time taken to calculate costs for g=41: 0.3894369602203369 seconds
# Lowest cost in generation 41: -946.63
# Time taken to sort population for g=41: 1.3828277587890625e-05 seconds
# Generation 43 of 100
# Time taken to breed kids for g=42: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=42: 0.0007410049438476562 seconds
# Time taken to evaluate population with C++ evaluator: 0.38492703437805176 seconds
# Time taken to calculate costs for g=42: 0.3887200355529785 seconds
# Lowest cost in generation 42: -946.63
# Time taken to sort population for g=42: 1.3113021850585938e-05 seconds
# Generation 44 of 100
# Time taken to breed kids for g=43: 8.440017700195312e-05 seconds
# Time taken to fill random members for g=43: 0.0007560253143310547 seconds
# Time taken to evaluate population with C++ evaluator: 0.3860490322113037 seconds
# Time taken to calculate costs for g=43: 0.3899071216583252 seconds
# Lowest cost in generation 43: -946.63
# Time taken to sort population for g=43: 1.2874603271484375e-05 seconds
# Generation 45 of 100
# Time taken to breed kids for g=44: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=44: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.38723182678222656 seconds
# Time taken to calculate costs for g=44: 0.3911018371582031 seconds
# Lowest cost in generation 44: -946.63
# Time taken to sort population for g=44: 1.3113021850585938e-05 seconds
# Generation 46 of 100
# Time taken to breed kids for g=45: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=45: 0.0007920265197753906 seconds
# Time taken to evaluate population with C++ evaluator: 0.385875940322876 seconds
# Time taken to calculate costs for g=45: 0.38965725898742676 seconds
# Lowest cost in generation 45: -946.63
# Time taken to sort population for g=45: 1.3113021850585938e-05 seconds
# Generation 47 of 100
# Time taken to breed kids for g=46: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=46: 0.0007309913635253906 seconds
# Time taken to evaluate population with C++ evaluator: 0.3886740207672119 seconds
# Time taken to calculate costs for g=46: 0.39263367652893066 seconds
# Lowest cost in generation 46: -946.63
# Time taken to sort population for g=46: 1.4066696166992188e-05 seconds
# Generation 48 of 100
# Time taken to breed kids for g=47: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=47: 0.0007772445678710938 seconds
# Time taken to evaluate population with C++ evaluator: 0.388293981552124 seconds
# Time taken to calculate costs for g=47: 0.39206600189208984 seconds
# Lowest cost in generation 47: -946.63
# Time taken to sort population for g=47: 1.2874603271484375e-05 seconds
# Generation 49 of 100
# Time taken to breed kids for g=48: 9.179115295410156e-05 seconds
# Time taken to fill random members for g=48: 0.0008289813995361328 seconds
# Time taken to evaluate population with C++ evaluator: 0.38385891914367676 seconds
# Time taken to calculate costs for g=48: 0.3878209590911865 seconds
# Lowest cost in generation 48: -946.63
# Time taken to sort population for g=48: 1.6927719116210938e-05 seconds
# Generation 50 of 100
# Time taken to breed kids for g=49: 8.988380432128906e-05 seconds
# Time taken to fill random members for g=49: 0.0008249282836914062 seconds
# Time taken to evaluate population with C++ evaluator: 0.3816370964050293 seconds
# Time taken to calculate costs for g=49: 0.3854231834411621 seconds
# Lowest cost in generation 49: -946.63
# Time taken to sort population for g=49: 1.3828277587890625e-05 seconds
# Generation 51 of 100
# Time taken to breed kids for g=50: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=50: 0.0007579326629638672 seconds
# Time taken to evaluate population with C++ evaluator: 0.3847949504852295 seconds
# Time taken to calculate costs for g=50: 0.38866710662841797 seconds
# Lowest cost in generation 50: -946.63
# Time taken to sort population for g=50: 1.2636184692382812e-05 seconds
# Generation 52 of 100
# Time taken to breed kids for g=51: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=51: 0.0007679462432861328 seconds
# Time taken to evaluate population with C++ evaluator: 0.38437414169311523 seconds
# Time taken to calculate costs for g=51: 0.38822221755981445 seconds
# Lowest cost in generation 51: -946.63
# Time taken to sort population for g=51: 1.3113021850585938e-05 seconds
# Generation 53 of 100
# Time taken to breed kids for g=52: 8.177757263183594e-05 seconds
# Time taken to fill random members for g=52: 0.0007417201995849609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3863348960876465 seconds
# Time taken to calculate costs for g=52: 0.39014482498168945 seconds
# Lowest cost in generation 52: -946.63
# Time taken to sort population for g=52: 1.2874603271484375e-05 seconds
# Generation 54 of 100
# Time taken to breed kids for g=53: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=53: 0.0007522106170654297 seconds
# Time taken to evaluate population with C++ evaluator: 0.3857882022857666 seconds
# Time taken to calculate costs for g=53: 0.38958191871643066 seconds
# Lowest cost in generation 53: -946.63
# Time taken to sort population for g=53: 1.2159347534179688e-05 seconds
# Generation 55 of 100
# Time taken to breed kids for g=54: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=54: 0.0007500648498535156 seconds
# Time taken to evaluate population with C++ evaluator: 0.3923311233520508 seconds
# Time taken to calculate costs for g=54: 0.3961310386657715 seconds
# Lowest cost in generation 54: -946.63
# Time taken to sort population for g=54: 1.3828277587890625e-05 seconds
# Generation 56 of 100
# Time taken to breed kids for g=55: 9.012222290039062e-05 seconds
# Time taken to fill random members for g=55: 0.0007450580596923828 seconds
# Time taken to evaluate population with C++ evaluator: 0.383220911026001 seconds
# Time taken to calculate costs for g=55: 0.3871290683746338 seconds
# Lowest cost in generation 55: -946.63
# Time taken to sort population for g=55: 1.2874603271484375e-05 seconds
# Generation 57 of 100
# Time taken to breed kids for g=56: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=56: 0.0007488727569580078 seconds
# Time taken to evaluate population with C++ evaluator: 0.3867628574371338 seconds
# Time taken to calculate costs for g=56: 0.3906540870666504 seconds
# Lowest cost in generation 56: -946.63
# Time taken to sort population for g=56: 1.3828277587890625e-05 seconds
# Generation 58 of 100
# Time taken to breed kids for g=57: 9.131431579589844e-05 seconds
# Time taken to fill random members for g=57: 0.0007369518280029297 seconds
# Time taken to evaluate population with C++ evaluator: 0.38573193550109863 seconds
# Time taken to calculate costs for g=57: 0.38948512077331543 seconds
# Lowest cost in generation 57: -946.63
# Time taken to sort population for g=57: 1.4066696166992188e-05 seconds
# Generation 59 of 100
# Time taken to breed kids for g=58: 8.392333984375e-05 seconds
# Time taken to fill random members for g=58: 0.0007431507110595703 seconds
# Time taken to evaluate population with C++ evaluator: 0.391071081161499 seconds
# Time taken to calculate costs for g=58: 0.3950209617614746 seconds
# Lowest cost in generation 58: -946.63
# Time taken to sort population for g=58: 1.3113021850585938e-05 seconds
# Generation 60 of 100
# Time taken to breed kids for g=59: 8.726119995117188e-05 seconds
# Time taken to fill random members for g=59: 0.0007390975952148438 seconds
# Time taken to evaluate population with C++ evaluator: 0.3827970027923584 seconds
# Time taken to calculate costs for g=59: 0.3865678310394287 seconds
# Lowest cost in generation 59: -946.63
# Time taken to sort population for g=59: 1.2874603271484375e-05 seconds
# Generation 61 of 100
# Time taken to breed kids for g=60: 8.20159912109375e-05 seconds
# Time taken to fill random members for g=60: 0.0007510185241699219 seconds
# Time taken to evaluate population with C++ evaluator: 0.387531042098999 seconds
# Time taken to calculate costs for g=60: 0.3912949562072754 seconds
# Lowest cost in generation 60: -946.63
# Time taken to sort population for g=60: 1.4066696166992188e-05 seconds
# Generation 62 of 100
# Time taken to breed kids for g=61: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=61: 0.0007460117340087891 seconds
# Time taken to evaluate population with C++ evaluator: 0.3885929584503174 seconds
# Time taken to calculate costs for g=61: 0.3923683166503906 seconds
# Lowest cost in generation 61: -946.63
# Time taken to sort population for g=61: 1.4066696166992188e-05 seconds
# Generation 63 of 100
# Time taken to breed kids for g=62: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=62: 0.0007832050323486328 seconds
# Time taken to evaluate population with C++ evaluator: 0.3848278522491455 seconds
# Time taken to calculate costs for g=62: 0.3887302875518799 seconds
# Lowest cost in generation 62: -946.63
# Time taken to sort population for g=62: 1.4066696166992188e-05 seconds
# Generation 64 of 100
# Time taken to breed kids for g=63: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=63: 0.000759124755859375 seconds
# Time taken to evaluate population with C++ evaluator: 0.3875598907470703 seconds
# Time taken to calculate costs for g=63: 0.39154505729675293 seconds
# Lowest cost in generation 63: -946.63
# Time taken to sort population for g=63: 1.3113021850585938e-05 seconds
# Generation 65 of 100
# Time taken to breed kids for g=64: 8.392333984375e-05 seconds
# Time taken to fill random members for g=64: 0.0007369518280029297 seconds
# Time taken to evaluate population with C++ evaluator: 0.38616013526916504 seconds
# Time taken to calculate costs for g=64: 0.38985204696655273 seconds
# Lowest cost in generation 64: -946.63
# Time taken to sort population for g=64: 1.3113021850585938e-05 seconds
# Generation 66 of 100
# Time taken to breed kids for g=65: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=65: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.3876919746398926 seconds
# Time taken to calculate costs for g=65: 0.3913908004760742 seconds
# Lowest cost in generation 65: -946.63
# Time taken to sort population for g=65: 1.4781951904296875e-05 seconds
# Generation 67 of 100
# Time taken to breed kids for g=66: 9.799003601074219e-05 seconds
# Time taken to fill random members for g=66: 0.0008161067962646484 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868880271911621 seconds
# Time taken to calculate costs for g=66: 0.39085960388183594 seconds
# Lowest cost in generation 66: -946.63
# Time taken to sort population for g=66: 1.2636184692382812e-05 seconds
# Generation 68 of 100
# Time taken to breed kids for g=67: 8.320808410644531e-05 seconds
# Time taken to fill random members for g=67: 0.0007159709930419922 seconds
# Time taken to evaluate population with C++ evaluator: 0.3881070613861084 seconds
# Time taken to calculate costs for g=67: 0.39193201065063477 seconds
# Lowest cost in generation 67: -946.63
# Time taken to sort population for g=67: 1.2874603271484375e-05 seconds
# Generation 69 of 100
# Time taken to breed kids for g=68: 8.0108642578125e-05 seconds
# Time taken to fill random members for g=68: 0.0007698535919189453 seconds
# Time taken to evaluate population with C++ evaluator: 0.38596391677856445 seconds
# Time taken to calculate costs for g=68: 0.3898308277130127 seconds
# Lowest cost in generation 68: -946.63
# Time taken to sort population for g=68: 1.3113021850585938e-05 seconds
# Generation 70 of 100
# Time taken to breed kids for g=69: 8.273124694824219e-05 seconds
# Time taken to fill random members for g=69: 0.0007169246673583984 seconds
# Time taken to evaluate population with C++ evaluator: 0.38854289054870605 seconds
# Time taken to calculate costs for g=69: 0.392333984375 seconds
# Lowest cost in generation 69: -946.63
# Time taken to sort population for g=69: 1.4781951904296875e-05 seconds
# Generation 71 of 100
# Time taken to breed kids for g=70: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=70: 0.0007040500640869141 seconds
# Time taken to evaluate population with C++ evaluator: 0.38904523849487305 seconds
# Time taken to calculate costs for g=70: 0.3929929733276367 seconds
# Lowest cost in generation 70: -946.63
# Time taken to sort population for g=70: 1.4066696166992188e-05 seconds
# Generation 72 of 100
# Time taken to breed kids for g=71: 8.392333984375e-05 seconds
# Time taken to fill random members for g=71: 0.0007359981536865234 seconds
# Time taken to evaluate population with C++ evaluator: 0.38627004623413086 seconds
# Time taken to calculate costs for g=71: 0.3899362087249756 seconds
# Lowest cost in generation 71: -946.63
# Time taken to sort population for g=71: 1.3828277587890625e-05 seconds
# Generation 73 of 100
# Time taken to breed kids for g=72: 9.703636169433594e-05 seconds
# Time taken to fill random members for g=72: 0.0007939338684082031 seconds
# Time taken to evaluate population with C++ evaluator: 0.3893251419067383 seconds
# Time taken to calculate costs for g=72: 0.3932459354400635 seconds
# Lowest cost in generation 72: -946.63
# Time taken to sort population for g=72: 1.1920928955078125e-05 seconds
# Generation 74 of 100
# Time taken to breed kids for g=73: 8.106231689453125e-05 seconds
# Time taken to fill random members for g=73: 0.0007059574127197266 seconds
# Time taken to evaluate population with C++ evaluator: 0.3854978084564209 seconds
# Time taken to calculate costs for g=73: 0.38946008682250977 seconds
# Lowest cost in generation 73: -946.63
# Time taken to sort population for g=73: 1.3113021850585938e-05 seconds
# Generation 75 of 100
# Time taken to breed kids for g=74: 8.678436279296875e-05 seconds
# Time taken to fill random members for g=74: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.38414692878723145 seconds
# Time taken to calculate costs for g=74: 0.3879988193511963 seconds
# Lowest cost in generation 74: -946.63
# Time taken to sort population for g=74: 1.4066696166992188e-05 seconds
# Generation 76 of 100
# Time taken to breed kids for g=75: 8.821487426757812e-05 seconds
# Time taken to fill random members for g=75: 0.0007767677307128906 seconds
# Time taken to evaluate population with C++ evaluator: 0.3841562271118164 seconds
# Time taken to calculate costs for g=75: 0.38802003860473633 seconds
# Lowest cost in generation 75: -946.63
# Time taken to sort population for g=75: 1.2874603271484375e-05 seconds
# Generation 77 of 100
# Time taken to breed kids for g=76: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=76: 0.0007760524749755859 seconds
# Time taken to evaluate population with C++ evaluator: 0.3859858512878418 seconds
# Time taken to calculate costs for g=76: 0.38982200622558594 seconds
# Lowest cost in generation 76: -946.63
# Time taken to sort population for g=76: 1.52587890625e-05 seconds
# Generation 78 of 100
# Time taken to breed kids for g=77: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=77: 0.0008800029754638672 seconds
# Time taken to evaluate population with C++ evaluator: 0.38515710830688477 seconds
# Time taken to calculate costs for g=77: 0.3892359733581543 seconds
# Lowest cost in generation 77: -946.63
# Time taken to sort population for g=77: 1.2636184692382812e-05 seconds
# Generation 79 of 100
# Time taken to breed kids for g=78: 8.606910705566406e-05 seconds
# Time taken to fill random members for g=78: 0.0008180141448974609 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868370056152344 seconds
# Time taken to calculate costs for g=78: 0.39072489738464355 seconds
# Lowest cost in generation 78: -946.63
# Time taken to sort population for g=78: 1.2874603271484375e-05 seconds
# Generation 80 of 100
# Time taken to breed kids for g=79: 8.702278137207031e-05 seconds
# Time taken to fill random members for g=79: 0.0007710456848144531 seconds
# Time taken to evaluate population with C++ evaluator: 0.38658976554870605 seconds
# Time taken to calculate costs for g=79: 0.3904447555541992 seconds
# Lowest cost in generation 79: -946.63
# Time taken to sort population for g=79: 1.621246337890625e-05 seconds
# Generation 81 of 100
# Time taken to breed kids for g=80: 9.608268737792969e-05 seconds
# Time taken to fill random members for g=80: 0.0008959770202636719 seconds
# Time taken to evaluate population with C++ evaluator: 0.3848721981048584 seconds
# Time taken to calculate costs for g=80: 0.38888096809387207 seconds
# Lowest cost in generation 80: -946.63
# Time taken to sort population for g=80: 1.3113021850585938e-05 seconds
# Generation 82 of 100
# Time taken to breed kids for g=81: 8.273124694824219e-05 seconds
# Time taken to fill random members for g=81: 0.0007660388946533203 seconds
# Time taken to evaluate population with C++ evaluator: 0.3869619369506836 seconds
# Time taken to calculate costs for g=81: 0.3908390998840332 seconds
# Lowest cost in generation 81: -946.63
# Time taken to sort population for g=81: 1.4066696166992188e-05 seconds
# Generation 83 of 100
# Time taken to breed kids for g=82: 8.916854858398438e-05 seconds
# Time taken to fill random members for g=82: 0.0007660388946533203 seconds
# Time taken to evaluate population with C++ evaluator: 0.3863718509674072 seconds
# Time taken to calculate costs for g=82: 0.3902580738067627 seconds
# Lowest cost in generation 82: -946.63
# Time taken to sort population for g=82: 1.2874603271484375e-05 seconds
# Generation 84 of 100
# Time taken to breed kids for g=83: 0.00010585784912109375 seconds
# Time taken to fill random members for g=83: 0.0007531642913818359 seconds
# Time taken to evaluate population with C++ evaluator: 0.384706974029541 seconds
# Time taken to calculate costs for g=83: 0.38859105110168457 seconds
# Lowest cost in generation 83: -946.63
# Time taken to sort population for g=83: 1.1920928955078125e-05 seconds
# Generation 85 of 100
# Time taken to breed kids for g=84: 8.416175842285156e-05 seconds
# Time taken to fill random members for g=84: 0.0007290840148925781 seconds
# Time taken to evaluate population with C++ evaluator: 0.3850529193878174 seconds
# Time taken to calculate costs for g=84: 0.38895320892333984 seconds
# Lowest cost in generation 84: -946.63
# Time taken to sort population for g=84: 1.4781951904296875e-05 seconds
# Generation 86 of 100
# Time taken to breed kids for g=85: 9.393692016601562e-05 seconds
# Time taken to fill random members for g=85: 0.0009028911590576172 seconds
# Time taken to evaluate population with C++ evaluator: 0.38347887992858887 seconds
# Time taken to calculate costs for g=85: 0.3872201442718506 seconds
# Lowest cost in generation 85: -946.63
# Time taken to sort population for g=85: 1.1920928955078125e-05 seconds
# Generation 87 of 100
# Time taken to breed kids for g=86: 8.0108642578125e-05 seconds
# Time taken to fill random members for g=86: 0.0007541179656982422 seconds
# Time taken to evaluate population with C++ evaluator: 0.386401891708374 seconds
# Time taken to calculate costs for g=86: 0.39022302627563477 seconds
# Lowest cost in generation 86: -946.63
# Time taken to sort population for g=86: 1.3828277587890625e-05 seconds
# Generation 88 of 100
# Time taken to breed kids for g=87: 9.083747863769531e-05 seconds
# Time taken to fill random members for g=87: 0.0007841587066650391 seconds
# Time taken to evaluate population with C++ evaluator: 0.3867299556732178 seconds
# Time taken to calculate costs for g=87: 0.3906717300415039 seconds
# Lowest cost in generation 87: -946.63
# Time taken to sort population for g=87: 1.3828277587890625e-05 seconds
# Generation 89 of 100
# Time taken to breed kids for g=88: 8.797645568847656e-05 seconds
# Time taken to fill random members for g=88: 0.0008091926574707031 seconds
# Time taken to evaluate population with C++ evaluator: 0.38853907585144043 seconds
# Time taken to calculate costs for g=88: 0.39231109619140625 seconds
# Lowest cost in generation 88: -946.63
# Time taken to sort population for g=88: 1.1920928955078125e-05 seconds
# Generation 90 of 100
# Time taken to breed kids for g=89: 8.225440979003906e-05 seconds
# Time taken to fill random members for g=89: 0.0007507801055908203 seconds
# Time taken to evaluate population with C++ evaluator: 0.3857419490814209 seconds
# Time taken to calculate costs for g=89: 0.38944172859191895 seconds
# Lowest cost in generation 89: -946.63
# Time taken to sort population for g=89: 1.2874603271484375e-05 seconds
# Generation 91 of 100
# Time taken to breed kids for g=90: 9.489059448242188e-05 seconds
# Time taken to fill random members for g=90: 0.0007190704345703125 seconds
# Time taken to evaluate population with C++ evaluator: 0.38846611976623535 seconds
# Time taken to calculate costs for g=90: 0.3924729824066162 seconds
# Lowest cost in generation 90: -946.63
# Time taken to sort population for g=90: 1.2159347534179688e-05 seconds
# Generation 92 of 100
# Time taken to breed kids for g=91: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=91: 0.0007317066192626953 seconds
# Time taken to evaluate population with C++ evaluator: 0.3868591785430908 seconds
# Time taken to calculate costs for g=91: 0.39066481590270996 seconds
# Lowest cost in generation 91: -946.63
# Time taken to sort population for g=91: 1.4066696166992188e-05 seconds
# Generation 93 of 100
# Time taken to breed kids for g=92: 8.678436279296875e-05 seconds
# Time taken to fill random members for g=92: 0.0007789134979248047 seconds
# Time taken to evaluate population with C++ evaluator: 0.3923208713531494 seconds
# Time taken to calculate costs for g=92: 0.3961308002471924 seconds
# Lowest cost in generation 92: -946.63
# Time taken to sort population for g=92: 1.2159347534179688e-05 seconds
# Generation 94 of 100
# Time taken to breed kids for g=93: 8.511543273925781e-05 seconds
# Time taken to fill random members for g=93: 0.0007758140563964844 seconds
# Time taken to evaluate population with C++ evaluator: 0.38808202743530273 seconds
# Time taken to calculate costs for g=93: 0.3918588161468506 seconds
# Lowest cost in generation 93: -946.63
# Time taken to sort population for g=93: 1.2159347534179688e-05 seconds
# Generation 95 of 100
# Time taken to breed kids for g=94: 8.487701416015625e-05 seconds
# Time taken to fill random members for g=94: 0.0007660388946533203 seconds
# Time taken to evaluate population with C++ evaluator: 0.39113783836364746 seconds
# Time taken to calculate costs for g=94: 0.39517807960510254 seconds
# Lowest cost in generation 94: -946.63
# Time taken to sort population for g=94: 1.3113021850585938e-05 seconds
# Generation 96 of 100
# Time taken to breed kids for g=95: 9.512901306152344e-05 seconds
# Time taken to fill random members for g=95: 0.0007779598236083984 seconds
# Time taken to evaluate population with C++ evaluator: 0.38924169540405273 seconds
# Time taken to calculate costs for g=95: 0.3931562900543213 seconds
# Lowest cost in generation 95: -946.63
# Time taken to sort population for g=95: 1.3113021850585938e-05 seconds
# Generation 97 of 100
# Time taken to breed kids for g=96: 8.106231689453125e-05 seconds
# Time taken to fill random members for g=96: 0.0007529258728027344 seconds
# Time taken to evaluate population with C++ evaluator: 0.38779282569885254 seconds
# Time taken to calculate costs for g=96: 0.39156413078308105 seconds
# Lowest cost in generation 96: -946.63
# Time taken to sort population for g=96: 1.3113021850585938e-05 seconds
# Generation 98 of 100
# Time taken to breed kids for g=97: 8.893013000488281e-05 seconds
# Time taken to fill random members for g=97: 0.0010671615600585938 seconds
# Time taken to evaluate population with C++ evaluator: 0.3893430233001709 seconds
# Time taken to calculate costs for g=97: 0.3928682804107666 seconds
# Lowest cost in generation 97: -946.63
# Time taken to sort population for g=97: 1.1682510375976562e-05 seconds
# Generation 99 of 100
# Time taken to breed kids for g=98: 8.082389831542969e-05 seconds
# Time taken to fill random members for g=98: 0.0007159709930419922 seconds
# Time taken to evaluate population with C++ evaluator: 0.38775014877319336 seconds
# Time taken to calculate costs for g=98: 0.39168524742126465 seconds
# Lowest cost in generation 98: -946.63
# Time taken to sort population for g=98: 1.621246337890625e-05 seconds
# Generation 100 of 100
# Time taken to breed kids for g=99: 8.296966552734375e-05 seconds
# Time taken to fill random members for g=99: 0.0007731914520263672 seconds
# Time taken to evaluate population with C++ evaluator: 0.38915205001831055 seconds
# Time taken to calculate costs for g=99: 0.39305925369262695 seconds
# Lowest cost in generation 99: -946.63
# Time taken to sort population for g=99: 1.3113021850585938e-05 seconds

# %%
with open(f"ga_parallel_results/pickled_ga_results/ga_parallel_result_{input_key}.pkl", "rb") as f:
    result = pickle.load(f)

# %%
[unique_values, unique_costs] = result.final_population.get_unique_designs()

# %%
unique_values_df = pd.DataFrame({
    'Irrigation frequency (every X hours)': unique_values[:, 0],
    'Irrigation amount (in)':               unique_values[:, 1],
    'Fertilizer frequency (every X hours)': unique_values[:, 2],
    'Fertilizer amount (lb)':               unique_values[:, 3],
    'Cost ($)':                             unique_costs,
    'Revenue ($)':                          -unique_costs,
})
unique_values_df.to_csv(f'ga_parallel_results/unique_values_costs_results/ga_parallel_result_unique_values_and_costs_{input_key}.csv', index=False)

# %%
#result.print_table_of_best_designs()

# %%
result.plot_optimization_results()

# %%
min(unique_costs)
# Out:
# np.float64(-975.3519320753132)
